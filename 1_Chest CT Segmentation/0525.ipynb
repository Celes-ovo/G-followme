# %% [markdown]
# # 1. Model 구현

# %%
# %load_ext tensorboard

# %%
import cv2, numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
tf.version
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\GC\\anaconda3\\envs\\sangmin_env\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
#rm -rf ./logs/

# %%
# Dice coefficient, IoU Metric

from tensorflow.keras import backend as K

def iou_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + K.epsilon())
	
def dice_coef_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %%
import keras
from keras import models, layers


def conv_3x3_relu(x, n):
    x = layers.Conv2D(n, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(max_value=None, negative_slope=0, threshold=0)(x)

    return x



def Unet(a, b, c, d):
    # a = input_size
    # b = 처음에 몇 채널로 시작할지
    # c = output channel의 개수.
    # d = activation function

    input = layers.Input(a)


    #Encoder

    x = conv_3x3_relu(input, b)
    down1 = conv_3x3_relu(x, b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down1)


    x = conv_3x3_relu(x, 2*b)
    down2 = conv_3x3_relu(x, 2*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down2)


    x = conv_3x3_relu(x, 4*b)
    down3 = conv_3x3_relu(x, 4*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down3)


    x = conv_3x3_relu(x, 8*b)
    down4 = conv_3x3_relu(x, 8*b)
    drop1 = layers.Dropout(0.3)(down4)
    x = layers.MaxPool2D(pool_size=(2, 2))(drop1)




    # Bottleneck

    x = conv_3x3_relu(x, 16*b)
    x = conv_3x3_relu(x, 16*b)
    drop2 = layers.Dropout(0.3)(x)




    # Decoder

    up1 = layers.Conv2DTranspose(8*b, (2, 2), strides=(2, 2))(drop2)
    merge1 = layers.concatenate([down4, up1], axis=3)
    x = conv_3x3_relu(merge1, 8*b)
    x = conv_3x3_relu(x, 8*b)
    x = conv_3x3_relu(x, 8*b)


    up2 = layers.Conv2DTranspose(4*b, (2, 2), strides=(2, 2))(x)
    merge2 = layers.concatenate([down3, up2], axis=3)
    x = conv_3x3_relu(merge2, 4*b)
    x = conv_3x3_relu(x, 4*b) 
    x = conv_3x3_relu(x, 4*b)


    up3 = layers.Conv2DTranspose(2*b, (2, 2), strides=(2, 2))(x)
    merge3 = layers.concatenate([down2, up3], axis=3)
    x = conv_3x3_relu(merge3, 2*b)
    x = conv_3x3_relu(x, 2*b) 
    x = conv_3x3_relu(x, 2*b)


    up4 = layers.Conv2DTranspose(b, (2, 2), strides=(2, 2))(x)
    merge4 = layers.concatenate([down1, up4], axis=3)
    x = conv_3x3_relu(merge4, b)
    x = conv_3x3_relu(x, b) 

    output = layers.Conv2D(c, (1, 1),name = 'result',activation = d)(x)

    Unet_model = models.Model(inputs=input, outputs=output)


    return Unet_model

# %% [markdown]
# ---
#
# ```# a = input_size
#     # b = 처음에 몇 채널로 시작할지
#     # c = output channel의 개수.
#     # d = activation function```

# %%
model = Unet((128, 128, 3), 32, 3, 'softmax')

# %% [markdown]
# # 2. Data load

# %%
import glob

data = glob.glob('.\\Data\\Chest CT Segmentation\\image\\image\\*.jpg')
label = glob.glob('.\\Data\\Chest CT Segmentation\\masks\\masks\\*.jpg')

# %%
print(len(data), len(label))
# Out:
# 16708 16708

# %%
def get_img(fstr):
    """
    jpg, png등의 영상을 읽어들임.
    numpy ndarray형으로 읽어들임.
    """
    img = cv2.imread(fstr)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (128, 128))
    #img = img/255.0
    #print(img.shape, img.dtype, np.max(img))
    return img

# %%
train_data = []
train_label = []

val_data = []
val_label = []

test_data = []
test_label = []


for i in range(8000):
    train_x = get_img(data[i])
    train_y = get_img(label[i])

    train_y[train_y < 240] = 0  # remove artifacts
    train_y[train_y >= 240] = 255
    
    #train_x = train_x/255.0
    #train_y = train_y/255.0
    
    train_data.append(train_x)
    train_label.append(train_y)
    
    
for i in range(2000):
    val_x = get_img(data[i+8000])
    val_y = get_img(label[i+8000])
    
    val_y[val_y < 240] = 0
    val_y[val_y >= 240] = 255
    
    #val_x = val_x/255.0
    #val_y = val_y/255.0
    
    val_data.append(val_x)
    val_label.append(val_y)
    

for i in range(1000):
    test_x = get_img(data[i+10000])
    test_y = get_img(label[i+10000])
    
    test_y[test_y < 240] = 0
    test_y[test_y >= 240] = 255
    
    #test_x = test_x/255.0
    #test_y = test_y/255.0
    
    test_data.append(test_x)
    test_label.append(test_y)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(221)
plt.imshow(train_data[15])

plt.subplot(222)
plt.imshow(train_label[15])

# %%
np.max(train_data[15])
# Out:
# 224

# %%
np.max(train_label[200])
# Out:
# 255

# %%
np.min(train_label[200])
# Out:
# 0

# %%
train_data = np.array(train_data)
train_label = np.array(train_label)

val_data = np.array(val_data)
val_label = np.array(val_label)

test_data = np.array(test_data)
test_label = np.array(test_label)


print(train_data.shape, train_label.shape, val_data.shape, val_label.shape, test_data.shape, test_label.shape, end='\n')
# Out:
# (8000, 128, 128, 3) (8000, 128, 128, 3) (2000, 128, 128, 3) (2000, 128, 128, 3) (1000, 128, 128, 3) (1000, 128, 128, 3)

# %%
train_data.shape
# Out:
# (8000, 128, 128, 3)

# %%
import datetime as dt

time_now = dt.datetime.now()
print(time_now.date())
# Out:
# 2022-05-25

# %%
np.save(f'./Data/Chest CT Segmentation/train_x_{time_now.date()}.npy', train_data)
np.save(f'./Data/Chest CT Segmentation/train_y_{time_now.date()}.npy', train_label)

np.save(f'./Data/Chest CT Segmentation/val_x_{time_now.date()}.npy', val_data)
np.save(f'./Data/Chest CT Segmentation/val_y_{time_now.date()}.npy', val_label)

np.save(f'./Data/Chest CT Segmentation/test_x_{time_now.date()}.npy', test_data)
np.save(f'./Data/Chest CT Segmentation/test_y_{time_now.date()}.npy', test_label)

# %%
#model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy, metrics='val_loss')
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-5), loss=tf.keras.losses.CategoricalCrossentropy(), metrics = ('accuracy', iou_gpu, dice_coef_gpu))

# %% [markdown]
# ### model checkpoint

# %%
from datetime import datetime

logdir="./log/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    f'./weight/{time_now.date()}_dice_model.h5',
    monitor='val_dice_coef_gpu',
    verbose=0,
    save_best_only=True,
    save_weights_only=False
)

tensorboard_callback = TensorBoard(log_dir=logdir, histogram_freq=1)

# %%
history = model.fit(train_data, train_label, epochs = 200, batch_size = 100 ,
                    validation_data = (val_data, val_label), 
                    callbacks=[model_checkpoint_callback, tensorboard_callback])
# Out:
# Epoch 1/200
#  1/80 [..............................] - ETA: 0s - loss: 32.6593 - accuracy: 0.3938 - iou_gpu: 0.3719 - dice_coef_gpu: 0.5421WARNING:tensorflow:From C:\Users\GC\anaconda3\envs\sangmin_env\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/80 [..............................] - ETA: 11s - loss: 35.7162 - accuracy: 0.3871 - iou_gpu: 0.3574 - dice_coef_gpu: 0.5264WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0088s vs `on_train_batch_end` time: 0.2723s). Check your callbacks.
# 80/80 [==============================] - ETA: 0s - loss: 31.5770 - accuracy: 0.3569 - iou_gpu: 0.4523 - dice_coef_gpu: 0.6194WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0580s). Check your callbacks.
# 80/80 [==============================] - 20s 255ms/step - loss: 31.5770 - accuracy: 0.3569 - iou_gpu: 0.4523 - dice_coef_gpu: 0.6194 - val_loss: 29.8118 - val_accuracy: 0.4322 - val_iou_gpu: 0.4490 - val_dice_coef_gpu: 0.6180
# Epoch 2/200
# 80/80 [==============================] - 20s 249ms/step - loss: 16.9510 - accuracy: 0.3498 - iou_gpu: 1.2394 - dice_coef_gpu: 1.0683 - val_loss: 27.2356 - val_accuracy: 0.5721 - val_iou_gpu: 0.5349 - val_dice_coef_gpu: 0.6939
# Epoch 3/200
# 80/80 [==============================] - 20s 249ms/step - loss: 7.4302 - accuracy: 0.4062 - iou_gpu: 3.2640 - dice_coef_gpu: 1.5197 - val_loss: 15.8883 - val_accuracy: 0.5230 - val_iou_gpu: 1.2949 - val_dice_coef_gpu: 1.0905
# Epoch 4/200
# 80/80 [==============================] - 20s 250ms/step - loss: 4.4909 - accuracy: 0.4334 - iou_gpu: 5.3058 - dice_coef_gpu: 1.6792 - val_loss: 10.9497 - val_accuracy: 0.4856 - val_iou_gpu: 2.3483 - val_dice_coef_gpu: 1.3305
# Epoch 5/200
# 80/80 [==============================] - 20s 252ms/step - loss: 2.9822 - accuracy: 0.4437 - iou_gpu: 7.2912 - dice_coef_gpu: 1.7573 - val_loss: 8.9586 - val_accuracy: 0.4676 - val_iou_gpu: 3.2515 - val_dice_coef_gpu: 1.4542
# Epoch 6/200
# 80/80 [==============================] - 20s 254ms/step - loss: 2.2538 - accuracy: 0.4497 - iou_gpu: 8.9718 - dice_coef_gpu: 1.7985 - val_loss: 6.3021 - val_accuracy: 0.4760 - val_iou_gpu: 4.6545 - val_dice_coef_gpu: 1.5708
# Epoch 7/200
# 80/80 [==============================] - 20s 256ms/step - loss: 1.8268 - accuracy: 0.4559 - iou_gpu: 10.2469 - dice_coef_gpu: 1.8219 - val_loss: 5.0453 - val_accuracy: 0.4864 - val_iou_gpu: 5.7529 - val_dice_coef_gpu: 1.6261
# Epoch 8/200
# 80/80 [==============================] - 20s 254ms/step - loss: 1.5715 - accuracy: 0.4613 - iou_gpu: 11.2566 - dice_coef_gpu: 1.8365 - val_loss: 4.0814 - val_accuracy: 0.4967 - val_iou_gpu: 6.5350 - val_dice_coef_gpu: 1.6649
# Epoch 9/200
# 80/80 [==============================] - 20s 251ms/step - loss: 1.3460 - accuracy: 0.4671 - iou_gpu: 12.2235 - dice_coef_gpu: 1.8485 - val_loss: 3.5646 - val_accuracy: 0.5048 - val_iou_gpu: 7.6914 - val_dice_coef_gpu: 1.7016
# Epoch 10/200
# 80/80 [==============================] - 20s 250ms/step - loss: 1.1926 - accuracy: 0.4733 - iou_gpu: 12.9888 - dice_coef_gpu: 1.8568 - val_loss: 3.1059 - val_accuracy: 0.5108 - val_iou_gpu: 8.0600 - val_dice_coef_gpu: 1.7115
# Epoch 11/200
# 80/80 [==============================] - 20s 250ms/step - loss: 1.0522 - accuracy: 0.4801 - iou_gpu: 13.7490 - dice_coef_gpu: 1.8642 - val_loss: 2.9248 - val_accuracy: 0.5111 - val_iou_gpu: 8.5701 - val_dice_coef_gpu: 1.7234
# Epoch 12/200
# 80/80 [==============================] - 20s 250ms/step - loss: 0.9501 - accuracy: 0.4876 - iou_gpu: 14.3555 - dice_coef_gpu: 1.8695 - val_loss: 2.8490 - val_accuracy: 0.5163 - val_iou_gpu: 8.8736 - val_dice_coef_gpu: 1.7287
# Epoch 13/200
# 80/80 [==============================] - 20s 250ms/step - loss: 0.8561 - accuracy: 0.4949 - iou_gpu: 14.9539 - dice_coef_gpu: 1.8744 - val_loss: 2.9920 - val_accuracy: 0.5149 - val_iou_gpu: 8.5957 - val_dice_coef_gpu: 1.7234
# Epoch 14/200
# 80/80 [==============================] - 20s 251ms/step - loss: 0.7775 - accuracy: 0.5019 - iou_gpu: 15.5116 - dice_coef_gpu: 1.8786 - val_loss: 2.5366 - val_accuracy: 0.5179 - val_iou_gpu: 10.2719 - val_dice_coef_gpu: 1.7491
# Epoch 15/200
# 80/80 [==============================] - 20s 254ms/step - loss: 0.7068 - accuracy: 0.5069 - iou_gpu: 16.0445 - dice_coef_gpu: 1.8824 - val_loss: 2.6399 - val_accuracy: 0.5197 - val_iou_gpu: 10.0076 - val_dice_coef_gpu: 1.7488
# Epoch 16/200
# 80/80 [==============================] - 20s 251ms/step - loss: 0.6497 - accuracy: 0.5130 - iou_gpu: 16.4975 - dice_coef_gpu: 1.8855 - val_loss: 1.9823 - val_accuracy: 0.5212 - val_iou_gpu: 11.0354 - val_dice_coef_gpu: 1.7685
# Epoch 17/200
# 80/80 [==============================] - 20s 252ms/step - loss: 0.5991 - accuracy: 0.5184 - iou_gpu: 16.9476 - dice_coef_gpu: 1.8883 - val_loss: 1.7756 - val_accuracy: 0.5301 - val_iou_gpu: 12.2032 - val_dice_coef_gpu: 1.7830
# Epoch 18/200
# 80/80 [==============================] - 20s 251ms/step - loss: 0.5532 - accuracy: 0.5214 - iou_gpu: 17.3428 - dice_coef_gpu: 1.8907 - val_loss: 2.1002 - val_accuracy: 0.5239 - val_iou_gpu: 11.4489 - val_dice_coef_gpu: 1.7689
# Epoch 19/200
# 80/80 [==============================] - 20s 252ms/step - loss: 0.5138 - accuracy: 0.5257 - iou_gpu: 17.7058 - dice_coef_gpu: 1.8928 - val_loss: 1.7200 - val_accuracy: 0.5341 - val_iou_gpu: 12.2858 - val_dice_coef_gpu: 1.7837
# Epoch 20/200
# 80/80 [==============================] - 20s 252ms/step - loss: 0.4707 - accuracy: 0.5296 - iou_gpu: 18.1337 - dice_coef_gpu: 1.8952 - val_loss: 1.8803 - val_accuracy: 0.5323 - val_iou_gpu: 11.7762 - val_dice_coef_gpu: 1.7771
# Epoch 21/200
# 80/80 [==============================] - 20s 253ms/step - loss: 0.4415 - accuracy: 0.5319 - iou_gpu: 18.4386 - dice_coef_gpu: 1.8968 - val_loss: 1.7254 - val_accuracy: 0.5405 - val_iou_gpu: 12.2418 - val_dice_coef_gpu: 1.7861
# Epoch 22/200
# 80/80 [==============================] - 20s 251ms/step - loss: 0.4014 - accuracy: 0.5344 - iou_gpu: 18.8550 - dice_coef_gpu: 1.8990 - val_loss: 1.6921 - val_accuracy: 0.5408 - val_iou_gpu: 12.6917 - val_dice_coef_gpu: 1.7891
# Epoch 23/200
# 80/80 [==============================] - 21s 257ms/step - loss: 0.3760 - accuracy: 0.5356 - iou_gpu: 19.1316 - dice_coef_gpu: 1.9003 - val_loss: 1.6774 - val_accuracy: 0.5550 - val_iou_gpu: 12.8659 - val_dice_coef_gpu: 1.7914
# Epoch 24/200
# 80/80 [==============================] - 21s 259ms/step - loss: 0.3478 - accuracy: 0.5346 - iou_gpu: 19.4795 - dice_coef_gpu: 1.9019 - val_loss: 1.6519 - val_accuracy: 0.5424 - val_iou_gpu: 13.1068 - val_dice_coef_gpu: 1.7917
# Epoch 25/200
# 80/80 [==============================] - 21s 258ms/step - loss: 0.3250 - accuracy: 0.5343 - iou_gpu: 19.7663 - dice_coef_gpu: 1.9033 - val_loss: 1.4576 - val_accuracy: 0.5371 - val_iou_gpu: 14.2317 - val_dice_coef_gpu: 1.8049
# Epoch 26/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.2972 - accuracy: 0.5294 - iou_gpu: 20.0972 - dice_coef_gpu: 1.9047 - val_loss: 1.4455 - val_accuracy: 0.5346 - val_iou_gpu: 13.7694 - val_dice_coef_gpu: 1.8015
# Epoch 27/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.2769 - accuracy: 0.5228 - iou_gpu: 20.3775 - dice_coef_gpu: 1.9060 - val_loss: 1.4263 - val_accuracy: 0.5295 - val_iou_gpu: 14.2619 - val_dice_coef_gpu: 1.8049
# Epoch 28/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.2580 - accuracy: 0.5156 - iou_gpu: 20.6616 - dice_coef_gpu: 1.9072 - val_loss: 1.4877 - val_accuracy: 0.5273 - val_iou_gpu: 14.1401 - val_dice_coef_gpu: 1.8034
# Epoch 29/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.2362 - accuracy: 0.5102 - iou_gpu: 20.9653 - dice_coef_gpu: 1.9086 - val_loss: 1.3087 - val_accuracy: 0.5216 - val_iou_gpu: 15.3272 - val_dice_coef_gpu: 1.8135
# Epoch 30/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.2180 - accuracy: 0.5040 - iou_gpu: 21.2379 - dice_coef_gpu: 1.9097 - val_loss: 1.3158 - val_accuracy: 0.5117 - val_iou_gpu: 15.2328 - val_dice_coef_gpu: 1.8117
# Epoch 31/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.2103 - accuracy: 0.4989 - iou_gpu: 21.4122 - dice_coef_gpu: 1.9104 - val_loss: 1.4345 - val_accuracy: 0.5189 - val_iou_gpu: 14.7459 - val_dice_coef_gpu: 1.8079
# Epoch 32/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1892 - accuracy: 0.4942 - iou_gpu: 21.7141 - dice_coef_gpu: 1.9116 - val_loss: 1.2735 - val_accuracy: 0.5037 - val_iou_gpu: 15.5678 - val_dice_coef_gpu: 1.8159
# Epoch 33/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1779 - accuracy: 0.4889 - iou_gpu: 21.8835 - dice_coef_gpu: 1.9122 - val_loss: 1.4526 - val_accuracy: 0.5050 - val_iou_gpu: 15.0269 - val_dice_coef_gpu: 1.8122
# Epoch 34/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1731 - accuracy: 0.4846 - iou_gpu: 21.9974 - dice_coef_gpu: 1.9125 - val_loss: 1.3493 - val_accuracy: 0.4972 - val_iou_gpu: 15.5423 - val_dice_coef_gpu: 1.8160
# Epoch 35/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1605 - accuracy: 0.4811 - iou_gpu: 22.1718 - dice_coef_gpu: 1.9131 - val_loss: 1.2491 - val_accuracy: 0.4874 - val_iou_gpu: 16.1532 - val_dice_coef_gpu: 1.8194
# Epoch 36/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1506 - accuracy: 0.4781 - iou_gpu: 22.3549 - dice_coef_gpu: 1.9140 - val_loss: 1.2991 - val_accuracy: 0.4890 - val_iou_gpu: 15.8316 - val_dice_coef_gpu: 1.8180
# Epoch 37/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1453 - accuracy: 0.4763 - iou_gpu: 22.4624 - dice_coef_gpu: 1.9143 - val_loss: 1.3275 - val_accuracy: 0.4769 - val_iou_gpu: 16.0443 - val_dice_coef_gpu: 1.8176
# Epoch 38/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1367 - accuracy: 0.4743 - iou_gpu: 22.5708 - dice_coef_gpu: 1.9146 - val_loss: 1.2692 - val_accuracy: 0.4857 - val_iou_gpu: 16.1730 - val_dice_coef_gpu: 1.8218
# Epoch 39/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1319 - accuracy: 0.4728 - iou_gpu: 22.6911 - dice_coef_gpu: 1.9152 - val_loss: 1.2712 - val_accuracy: 0.4896 - val_iou_gpu: 16.2430 - val_dice_coef_gpu: 1.8220
# Epoch 40/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1266 - accuracy: 0.4720 - iou_gpu: 22.7489 - dice_coef_gpu: 1.9151 - val_loss: 1.1682 - val_accuracy: 0.4710 - val_iou_gpu: 16.6641 - val_dice_coef_gpu: 1.8236
# Epoch 41/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1209 - accuracy: 0.4701 - iou_gpu: 22.8682 - dice_coef_gpu: 1.9158 - val_loss: 1.1267 - val_accuracy: 0.4678 - val_iou_gpu: 16.9677 - val_dice_coef_gpu: 1.8273
# Epoch 42/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1163 - accuracy: 0.4701 - iou_gpu: 22.9508 - dice_coef_gpu: 1.9161 - val_loss: 1.1560 - val_accuracy: 0.4716 - val_iou_gpu: 16.6903 - val_dice_coef_gpu: 1.8264
# Epoch 43/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1108 - accuracy: 0.4686 - iou_gpu: 23.0412 - dice_coef_gpu: 1.9163 - val_loss: 1.2460 - val_accuracy: 0.4631 - val_iou_gpu: 16.7986 - val_dice_coef_gpu: 1.8248
# Epoch 44/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1049 - accuracy: 0.4690 - iou_gpu: 23.1333 - dice_coef_gpu: 1.9166 - val_loss: 1.2522 - val_accuracy: 0.4652 - val_iou_gpu: 16.4977 - val_dice_coef_gpu: 1.8220
# Epoch 45/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.1018 - accuracy: 0.4678 - iou_gpu: 23.1865 - dice_coef_gpu: 1.9167 - val_loss: 1.3164 - val_accuracy: 0.4712 - val_iou_gpu: 16.2733 - val_dice_coef_gpu: 1.8209
# Epoch 46/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0979 - accuracy: 0.4671 - iou_gpu: 23.2749 - dice_coef_gpu: 1.9171 - val_loss: 1.0977 - val_accuracy: 0.4564 - val_iou_gpu: 17.5969 - val_dice_coef_gpu: 1.8301
# Epoch 47/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0935 - accuracy: 0.4672 - iou_gpu: 23.3444 - dice_coef_gpu: 1.9175 - val_loss: 1.1545 - val_accuracy: 0.4557 - val_iou_gpu: 17.3518 - val_dice_coef_gpu: 1.8273
# Epoch 48/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0908 - accuracy: 0.4676 - iou_gpu: 23.3970 - dice_coef_gpu: 1.9175 - val_loss: 1.1650 - val_accuracy: 0.4490 - val_iou_gpu: 17.3045 - val_dice_coef_gpu: 1.8285
# Epoch 49/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0884 - accuracy: 0.4677 - iou_gpu: 23.4387 - dice_coef_gpu: 1.9176 - val_loss: 1.1689 - val_accuracy: 0.4614 - val_iou_gpu: 17.0228 - val_dice_coef_gpu: 1.8276
# Epoch 50/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0870 - accuracy: 0.4684 - iou_gpu: 23.4666 - dice_coef_gpu: 1.9177 - val_loss: 1.0792 - val_accuracy: 0.4540 - val_iou_gpu: 17.7100 - val_dice_coef_gpu: 1.8316
# Epoch 51/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0831 - accuracy: 0.4695 - iou_gpu: 23.5464 - dice_coef_gpu: 1.9180 - val_loss: 1.1760 - val_accuracy: 0.4711 - val_iou_gpu: 17.3360 - val_dice_coef_gpu: 1.8293
# Epoch 52/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0813 - accuracy: 0.4699 - iou_gpu: 23.5743 - dice_coef_gpu: 1.9180 - val_loss: 1.0687 - val_accuracy: 0.4703 - val_iou_gpu: 18.6478 - val_dice_coef_gpu: 1.8361
# Epoch 53/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0794 - accuracy: 0.4702 - iou_gpu: 23.6221 - dice_coef_gpu: 1.9183 - val_loss: 1.0882 - val_accuracy: 0.4693 - val_iou_gpu: 17.9111 - val_dice_coef_gpu: 1.8324
# Epoch 54/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0759 - accuracy: 0.4724 - iou_gpu: 23.6750 - dice_coef_gpu: 1.9184 - val_loss: 1.1087 - val_accuracy: 0.4616 - val_iou_gpu: 17.7074 - val_dice_coef_gpu: 1.8309
# Epoch 55/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0756 - accuracy: 0.4734 - iou_gpu: 23.6867 - dice_coef_gpu: 1.9184 - val_loss: 1.1821 - val_accuracy: 0.4695 - val_iou_gpu: 17.5928 - val_dice_coef_gpu: 1.8290
# Epoch 56/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0721 - accuracy: 0.4740 - iou_gpu: 23.7687 - dice_coef_gpu: 1.9188 - val_loss: 1.1278 - val_accuracy: 0.4857 - val_iou_gpu: 18.0472 - val_dice_coef_gpu: 1.8341
# Epoch 57/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0680 - accuracy: 0.4745 - iou_gpu: 23.8221 - dice_coef_gpu: 1.9190 - val_loss: 0.9924 - val_accuracy: 0.4754 - val_iou_gpu: 18.6133 - val_dice_coef_gpu: 1.8367
# Epoch 58/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0662 - accuracy: 0.4779 - iou_gpu: 23.8720 - dice_coef_gpu: 1.9192 - val_loss: 1.0132 - val_accuracy: 0.4707 - val_iou_gpu: 18.3104 - val_dice_coef_gpu: 1.8352
# Epoch 59/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0664 - accuracy: 0.4783 - iou_gpu: 23.8726 - dice_coef_gpu: 1.9190 - val_loss: 1.0572 - val_accuracy: 0.4733 - val_iou_gpu: 18.2769 - val_dice_coef_gpu: 1.8344
# Epoch 60/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0635 - accuracy: 0.4777 - iou_gpu: 23.9053 - dice_coef_gpu: 1.9190 - val_loss: 1.2802 - val_accuracy: 0.4908 - val_iou_gpu: 17.8386 - val_dice_coef_gpu: 1.8315
# Epoch 61/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0602 - accuracy: 0.4827 - iou_gpu: 23.9709 - dice_coef_gpu: 1.9194 - val_loss: 1.0627 - val_accuracy: 0.4745 - val_iou_gpu: 18.2590 - val_dice_coef_gpu: 1.8339
# Epoch 62/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0651 - accuracy: 0.4850 - iou_gpu: 23.9336 - dice_coef_gpu: 1.9193 - val_loss: 1.1653 - val_accuracy: 0.4590 - val_iou_gpu: 17.8275 - val_dice_coef_gpu: 1.8319
# Epoch 63/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0614 - accuracy: 0.4878 - iou_gpu: 23.9885 - dice_coef_gpu: 1.9195 - val_loss: 1.0439 - val_accuracy: 0.4848 - val_iou_gpu: 18.9108 - val_dice_coef_gpu: 1.8381
# Epoch 64/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0579 - accuracy: 0.4881 - iou_gpu: 24.0306 - dice_coef_gpu: 1.9195 - val_loss: 1.1139 - val_accuracy: 0.4970 - val_iou_gpu: 18.4303 - val_dice_coef_gpu: 1.8346
# Epoch 65/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0553 - accuracy: 0.4930 - iou_gpu: 24.0910 - dice_coef_gpu: 1.9197 - val_loss: 1.0555 - val_accuracy: 0.4956 - val_iou_gpu: 18.4234 - val_dice_coef_gpu: 1.8349
# Epoch 66/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0552 - accuracy: 0.4955 - iou_gpu: 24.0860 - dice_coef_gpu: 1.9196 - val_loss: 1.0485 - val_accuracy: 0.5009 - val_iou_gpu: 18.8582 - val_dice_coef_gpu: 1.8383
# Epoch 67/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0509 - accuracy: 0.4975 - iou_gpu: 24.1614 - dice_coef_gpu: 1.9200 - val_loss: 1.1242 - val_accuracy: 0.4950 - val_iou_gpu: 18.0136 - val_dice_coef_gpu: 1.8320
# Epoch 68/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0489 - accuracy: 0.5024 - iou_gpu: 24.2056 - dice_coef_gpu: 1.9202 - val_loss: 1.0257 - val_accuracy: 0.4966 - val_iou_gpu: 18.9968 - val_dice_coef_gpu: 1.8386
# Epoch 69/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0487 - accuracy: 0.5077 - iou_gpu: 24.2027 - dice_coef_gpu: 1.9200 - val_loss: 1.0590 - val_accuracy: 0.4933 - val_iou_gpu: 19.1471 - val_dice_coef_gpu: 1.8365
# Epoch 70/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0488 - accuracy: 0.5113 - iou_gpu: 24.2111 - dice_coef_gpu: 1.9201 - val_loss: 1.0268 - val_accuracy: 0.5088 - val_iou_gpu: 18.7538 - val_dice_coef_gpu: 1.8363
# Epoch 71/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0460 - accuracy: 0.5125 - iou_gpu: 24.2720 - dice_coef_gpu: 1.9205 - val_loss: 1.0127 - val_accuracy: 0.5061 - val_iou_gpu: 19.1172 - val_dice_coef_gpu: 1.8381
# Epoch 72/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0433 - accuracy: 0.5179 - iou_gpu: 24.3200 - dice_coef_gpu: 1.9206 - val_loss: 1.1649 - val_accuracy: 0.5078 - val_iou_gpu: 18.1975 - val_dice_coef_gpu: 1.8317
# Epoch 73/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0470 - accuracy: 0.5202 - iou_gpu: 24.2623 - dice_coef_gpu: 1.9203 - val_loss: 1.1751 - val_accuracy: 0.5109 - val_iou_gpu: 18.8503 - val_dice_coef_gpu: 1.8357
# Epoch 74/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0452 - accuracy: 0.5271 - iou_gpu: 24.2813 - dice_coef_gpu: 1.9202 - val_loss: 1.3084 - val_accuracy: 0.5493 - val_iou_gpu: 17.9910 - val_dice_coef_gpu: 1.8283
# Epoch 75/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0408 - accuracy: 0.5299 - iou_gpu: 24.3671 - dice_coef_gpu: 1.9207 - val_loss: 1.2412 - val_accuracy: 0.5350 - val_iou_gpu: 18.3187 - val_dice_coef_gpu: 1.8302
# Epoch 76/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0405 - accuracy: 0.5321 - iou_gpu: 24.3697 - dice_coef_gpu: 1.9206 - val_loss: 1.0879 - val_accuracy: 0.5387 - val_iou_gpu: 18.4551 - val_dice_coef_gpu: 1.8337
# Epoch 77/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0392 - accuracy: 0.5352 - iou_gpu: 24.4068 - dice_coef_gpu: 1.9207 - val_loss: 1.0683 - val_accuracy: 0.5534 - val_iou_gpu: 19.0421 - val_dice_coef_gpu: 1.8361
# Epoch 78/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0376 - accuracy: 0.5403 - iou_gpu: 24.4202 - dice_coef_gpu: 1.9205 - val_loss: 1.1708 - val_accuracy: 0.5609 - val_iou_gpu: 18.3729 - val_dice_coef_gpu: 1.8324
# Epoch 79/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0382 - accuracy: 0.5463 - iou_gpu: 24.4317 - dice_coef_gpu: 1.9208 - val_loss: 1.0970 - val_accuracy: 0.5566 - val_iou_gpu: 18.6136 - val_dice_coef_gpu: 1.8343
# Epoch 80/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0354 - accuracy: 0.5475 - iou_gpu: 24.4648 - dice_coef_gpu: 1.9208 - val_loss: 1.0026 - val_accuracy: 0.5582 - val_iou_gpu: 19.2643 - val_dice_coef_gpu: 1.8391
# Epoch 81/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0343 - accuracy: 0.5509 - iou_gpu: 24.5041 - dice_coef_gpu: 1.9211 - val_loss: 1.0639 - val_accuracy: 0.5654 - val_iou_gpu: 19.2110 - val_dice_coef_gpu: 1.8381
# Epoch 82/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0343 - accuracy: 0.5538 - iou_gpu: 24.5019 - dice_coef_gpu: 1.9210 - val_loss: 1.1014 - val_accuracy: 0.5678 - val_iou_gpu: 18.7906 - val_dice_coef_gpu: 1.8349
# Epoch 83/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0349 - accuracy: 0.5589 - iou_gpu: 24.5032 - dice_coef_gpu: 1.9210 - val_loss: 1.1874 - val_accuracy: 0.5767 - val_iou_gpu: 17.9160 - val_dice_coef_gpu: 1.8312
# Epoch 84/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0353 - accuracy: 0.5616 - iou_gpu: 24.4865 - dice_coef_gpu: 1.9209 - val_loss: 1.1638 - val_accuracy: 0.5973 - val_iou_gpu: 18.6550 - val_dice_coef_gpu: 1.8358
# Epoch 85/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0324 - accuracy: 0.5668 - iou_gpu: 24.5420 - dice_coef_gpu: 1.9211 - val_loss: 1.0292 - val_accuracy: 0.5846 - val_iou_gpu: 18.9848 - val_dice_coef_gpu: 1.8381
# Epoch 86/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0313 - accuracy: 0.5716 - iou_gpu: 24.5637 - dice_coef_gpu: 1.9213 - val_loss: 0.9480 - val_accuracy: 0.5856 - val_iou_gpu: 19.6898 - val_dice_coef_gpu: 1.8433
# Epoch 87/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0308 - accuracy: 0.5730 - iou_gpu: 24.5705 - dice_coef_gpu: 1.9210 - val_loss: 1.0510 - val_accuracy: 0.5844 - val_iou_gpu: 18.7314 - val_dice_coef_gpu: 1.8366
# Epoch 88/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0308 - accuracy: 0.5759 - iou_gpu: 24.5806 - dice_coef_gpu: 1.9211 - val_loss: 1.1553 - val_accuracy: 0.5918 - val_iou_gpu: 19.1327 - val_dice_coef_gpu: 1.8392
# Epoch 89/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0289 - accuracy: 0.5769 - iou_gpu: 24.6127 - dice_coef_gpu: 1.9214 - val_loss: 1.0203 - val_accuracy: 0.5921 - val_iou_gpu: 19.2328 - val_dice_coef_gpu: 1.8384
# Epoch 90/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0288 - accuracy: 0.5816 - iou_gpu: 24.6174 - dice_coef_gpu: 1.9212 - val_loss: 1.0051 - val_accuracy: 0.6044 - val_iou_gpu: 19.5071 - val_dice_coef_gpu: 1.8402
# Epoch 91/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0301 - accuracy: 0.5829 - iou_gpu: 24.6093 - dice_coef_gpu: 1.9214 - val_loss: 1.1042 - val_accuracy: 0.6012 - val_iou_gpu: 18.2808 - val_dice_coef_gpu: 1.8351
# Epoch 92/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0279 - accuracy: 0.5833 - iou_gpu: 24.6404 - dice_coef_gpu: 1.9215 - val_loss: 0.9719 - val_accuracy: 0.6052 - val_iou_gpu: 19.7407 - val_dice_coef_gpu: 1.8429
# Epoch 93/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0288 - accuracy: 0.5874 - iou_gpu: 24.6316 - dice_coef_gpu: 1.9212 - val_loss: 1.0426 - val_accuracy: 0.6096 - val_iou_gpu: 18.9253 - val_dice_coef_gpu: 1.8378
# Epoch 94/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0329 - accuracy: 0.5879 - iou_gpu: 24.5840 - dice_coef_gpu: 1.9213 - val_loss: 1.2214 - val_accuracy: 0.6188 - val_iou_gpu: 18.8687 - val_dice_coef_gpu: 1.8331
# Epoch 95/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0287 - accuracy: 0.5941 - iou_gpu: 24.6304 - dice_coef_gpu: 1.9212 - val_loss: 1.0542 - val_accuracy: 0.6315 - val_iou_gpu: 19.3850 - val_dice_coef_gpu: 1.8381
# Epoch 96/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0247 - accuracy: 0.5927 - iou_gpu: 24.7002 - dice_coef_gpu: 1.9216 - val_loss: 0.9633 - val_accuracy: 0.6115 - val_iou_gpu: 19.6464 - val_dice_coef_gpu: 1.8409
# Epoch 97/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0251 - accuracy: 0.5954 - iou_gpu: 24.6920 - dice_coef_gpu: 1.9216 - val_loss: 0.9127 - val_accuracy: 0.6329 - val_iou_gpu: 19.5862 - val_dice_coef_gpu: 1.8428
# Epoch 98/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0251 - accuracy: 0.5970 - iou_gpu: 24.6872 - dice_coef_gpu: 1.9213 - val_loss: 1.0068 - val_accuracy: 0.6136 - val_iou_gpu: 19.4585 - val_dice_coef_gpu: 1.8400
# Epoch 99/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0237 - accuracy: 0.5978 - iou_gpu: 24.7233 - dice_coef_gpu: 1.9215 - val_loss: 1.0209 - val_accuracy: 0.6260 - val_iou_gpu: 18.9919 - val_dice_coef_gpu: 1.8383
# Epoch 100/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0235 - accuracy: 0.5994 - iou_gpu: 24.7180 - dice_coef_gpu: 1.9213 - val_loss: 0.9390 - val_accuracy: 0.6200 - val_iou_gpu: 19.5517 - val_dice_coef_gpu: 1.8425
# Epoch 101/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0225 - accuracy: 0.5998 - iou_gpu: 24.7475 - dice_coef_gpu: 1.9216 - val_loss: 0.9849 - val_accuracy: 0.5960 - val_iou_gpu: 19.4532 - val_dice_coef_gpu: 1.8398
# Epoch 102/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0224 - accuracy: 0.6015 - iou_gpu: 24.7527 - dice_coef_gpu: 1.9217 - val_loss: 0.9974 - val_accuracy: 0.6158 - val_iou_gpu: 19.5134 - val_dice_coef_gpu: 1.8398
# Epoch 103/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0215 - accuracy: 0.6036 - iou_gpu: 24.7688 - dice_coef_gpu: 1.9216 - val_loss: 0.9381 - val_accuracy: 0.6174 - val_iou_gpu: 19.6185 - val_dice_coef_gpu: 1.8426
# Epoch 104/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0216 - accuracy: 0.6031 - iou_gpu: 24.7704 - dice_coef_gpu: 1.9218 - val_loss: 0.9656 - val_accuracy: 0.6218 - val_iou_gpu: 19.4971 - val_dice_coef_gpu: 1.8416
# Epoch 105/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0209 - accuracy: 0.6045 - iou_gpu: 24.7829 - dice_coef_gpu: 1.9218 - val_loss: 0.9077 - val_accuracy: 0.6275 - val_iou_gpu: 20.1794 - val_dice_coef_gpu: 1.8448
# Epoch 106/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0204 - accuracy: 0.6059 - iou_gpu: 24.7932 - dice_coef_gpu: 1.9219 - val_loss: 1.0302 - val_accuracy: 0.6268 - val_iou_gpu: 19.4358 - val_dice_coef_gpu: 1.8405
# Epoch 107/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0350 - accuracy: 0.6030 - iou_gpu: 24.6202 - dice_coef_gpu: 1.9211 - val_loss: 1.3683 - val_accuracy: 0.5844 - val_iou_gpu: 18.9944 - val_dice_coef_gpu: 1.8321
# Epoch 108/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0223 - accuracy: 0.6052 - iou_gpu: 24.7618 - dice_coef_gpu: 1.9218 - val_loss: 1.0639 - val_accuracy: 0.6244 - val_iou_gpu: 19.8806 - val_dice_coef_gpu: 1.8427
# Epoch 109/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0204 - accuracy: 0.6080 - iou_gpu: 24.7982 - dice_coef_gpu: 1.9219 - val_loss: 1.0394 - val_accuracy: 0.6303 - val_iou_gpu: 20.2474 - val_dice_coef_gpu: 1.8439
# Epoch 110/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0192 - accuracy: 0.6103 - iou_gpu: 24.8149 - dice_coef_gpu: 1.9219 - val_loss: 1.1545 - val_accuracy: 0.6319 - val_iou_gpu: 19.7972 - val_dice_coef_gpu: 1.8417
# Epoch 111/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0191 - accuracy: 0.6105 - iou_gpu: 24.8183 - dice_coef_gpu: 1.9219 - val_loss: 1.1745 - val_accuracy: 0.6314 - val_iou_gpu: 19.9481 - val_dice_coef_gpu: 1.8430
# Epoch 112/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0191 - accuracy: 0.6107 - iou_gpu: 24.8197 - dice_coef_gpu: 1.9219 - val_loss: 1.0883 - val_accuracy: 0.6327 - val_iou_gpu: 20.0273 - val_dice_coef_gpu: 1.8442
# Epoch 113/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0179 - accuracy: 0.6114 - iou_gpu: 24.8455 - dice_coef_gpu: 1.9221 - val_loss: 1.0768 - val_accuracy: 0.6419 - val_iou_gpu: 20.1119 - val_dice_coef_gpu: 1.8435
# Epoch 114/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0191 - accuracy: 0.6128 - iou_gpu: 24.8359 - dice_coef_gpu: 1.9219 - val_loss: 1.2724 - val_accuracy: 0.6276 - val_iou_gpu: 19.7208 - val_dice_coef_gpu: 1.8415
# Epoch 115/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0191 - accuracy: 0.6094 - iou_gpu: 24.8318 - dice_coef_gpu: 1.9218 - val_loss: 1.1612 - val_accuracy: 0.6412 - val_iou_gpu: 20.0833 - val_dice_coef_gpu: 1.8427
# Epoch 116/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0176 - accuracy: 0.6128 - iou_gpu: 24.8490 - dice_coef_gpu: 1.9219 - val_loss: 1.0788 - val_accuracy: 0.6368 - val_iou_gpu: 20.3000 - val_dice_coef_gpu: 1.8434
# Epoch 117/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0175 - accuracy: 0.6147 - iou_gpu: 24.8594 - dice_coef_gpu: 1.9220 - val_loss: 1.0656 - val_accuracy: 0.6416 - val_iou_gpu: 20.0192 - val_dice_coef_gpu: 1.8424
# Epoch 118/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0168 - accuracy: 0.6139 - iou_gpu: 24.8735 - dice_coef_gpu: 1.9220 - val_loss: 1.1595 - val_accuracy: 0.6438 - val_iou_gpu: 19.6168 - val_dice_coef_gpu: 1.8408
# Epoch 119/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0160 - accuracy: 0.6113 - iou_gpu: 24.8872 - dice_coef_gpu: 1.9221 - val_loss: 1.0547 - val_accuracy: 0.6280 - val_iou_gpu: 20.3685 - val_dice_coef_gpu: 1.8440
# Epoch 120/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0157 - accuracy: 0.6140 - iou_gpu: 24.8934 - dice_coef_gpu: 1.9220 - val_loss: 1.1479 - val_accuracy: 0.6369 - val_iou_gpu: 19.6285 - val_dice_coef_gpu: 1.8404
# Epoch 121/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0160 - accuracy: 0.6149 - iou_gpu: 24.8916 - dice_coef_gpu: 1.9220 - val_loss: 1.1252 - val_accuracy: 0.6409 - val_iou_gpu: 19.4609 - val_dice_coef_gpu: 1.8395
# Epoch 122/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0155 - accuracy: 0.6166 - iou_gpu: 24.9021 - dice_coef_gpu: 1.9220 - val_loss: 1.1145 - val_accuracy: 0.6273 - val_iou_gpu: 20.4331 - val_dice_coef_gpu: 1.8435
# Epoch 123/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0150 - accuracy: 0.6174 - iou_gpu: 24.9099 - dice_coef_gpu: 1.9222 - val_loss: 1.1230 - val_accuracy: 0.6353 - val_iou_gpu: 19.6275 - val_dice_coef_gpu: 1.8407
# Epoch 124/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0151 - accuracy: 0.6146 - iou_gpu: 24.9080 - dice_coef_gpu: 1.9223 - val_loss: 1.0619 - val_accuracy: 0.6371 - val_iou_gpu: 20.1337 - val_dice_coef_gpu: 1.8426
# Epoch 125/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0148 - accuracy: 0.6175 - iou_gpu: 24.9122 - dice_coef_gpu: 1.9222 - val_loss: 1.0483 - val_accuracy: 0.6340 - val_iou_gpu: 20.1263 - val_dice_coef_gpu: 1.8429
# Epoch 126/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0143 - accuracy: 0.6199 - iou_gpu: 24.9231 - dice_coef_gpu: 1.9221 - val_loss: 1.0268 - val_accuracy: 0.6375 - val_iou_gpu: 20.2225 - val_dice_coef_gpu: 1.8438
# Epoch 127/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0138 - accuracy: 0.6193 - iou_gpu: 24.9342 - dice_coef_gpu: 1.9222 - val_loss: 1.0818 - val_accuracy: 0.6466 - val_iou_gpu: 20.3498 - val_dice_coef_gpu: 1.8439
# Epoch 128/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0138 - accuracy: 0.6202 - iou_gpu: 24.9327 - dice_coef_gpu: 1.9221 - val_loss: 0.9952 - val_accuracy: 0.6350 - val_iou_gpu: 20.4983 - val_dice_coef_gpu: 1.8454
# Epoch 129/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0136 - accuracy: 0.6207 - iou_gpu: 24.9377 - dice_coef_gpu: 1.9222 - val_loss: 1.0424 - val_accuracy: 0.6310 - val_iou_gpu: 20.1301 - val_dice_coef_gpu: 1.8421
# Epoch 130/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0134 - accuracy: 0.6214 - iou_gpu: 24.9422 - dice_coef_gpu: 1.9223 - val_loss: 1.0580 - val_accuracy: 0.6337 - val_iou_gpu: 20.0313 - val_dice_coef_gpu: 1.8431
# Epoch 131/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0135 - accuracy: 0.6193 - iou_gpu: 24.9439 - dice_coef_gpu: 1.9222 - val_loss: 1.0331 - val_accuracy: 0.6491 - val_iou_gpu: 19.9607 - val_dice_coef_gpu: 1.8429
# Epoch 132/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0131 - accuracy: 0.6231 - iou_gpu: 24.9532 - dice_coef_gpu: 1.9222 - val_loss: 1.0151 - val_accuracy: 0.6448 - val_iou_gpu: 20.4222 - val_dice_coef_gpu: 1.8446
# Epoch 133/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0128 - accuracy: 0.6223 - iou_gpu: 24.9578 - dice_coef_gpu: 1.9223 - val_loss: 1.0822 - val_accuracy: 0.6420 - val_iou_gpu: 20.2384 - val_dice_coef_gpu: 1.8435
# Epoch 134/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0118 - accuracy: 0.6243 - iou_gpu: 24.9723 - dice_coef_gpu: 1.9224 - val_loss: 1.1643 - val_accuracy: 0.6418 - val_iou_gpu: 20.2866 - val_dice_coef_gpu: 1.8442
# Epoch 135/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0135 - accuracy: 0.6252 - iou_gpu: 24.9589 - dice_coef_gpu: 1.9224 - val_loss: 1.1066 - val_accuracy: 0.6373 - val_iou_gpu: 19.7392 - val_dice_coef_gpu: 1.8411
# Epoch 136/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0142 - accuracy: 0.6247 - iou_gpu: 24.9430 - dice_coef_gpu: 1.9222 - val_loss: 1.1020 - val_accuracy: 0.6434 - val_iou_gpu: 20.3656 - val_dice_coef_gpu: 1.8438
# Epoch 137/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0125 - accuracy: 0.6239 - iou_gpu: 24.9651 - dice_coef_gpu: 1.9224 - val_loss: 1.1674 - val_accuracy: 0.6392 - val_iou_gpu: 20.2074 - val_dice_coef_gpu: 1.8441
# Epoch 138/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0116 - accuracy: 0.6252 - iou_gpu: 24.9833 - dice_coef_gpu: 1.9225 - val_loss: 1.1631 - val_accuracy: 0.6548 - val_iou_gpu: 19.8008 - val_dice_coef_gpu: 1.8421
# Epoch 139/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0125 - accuracy: 0.6229 - iou_gpu: 24.9687 - dice_coef_gpu: 1.9224 - val_loss: 1.0739 - val_accuracy: 0.6477 - val_iou_gpu: 20.0221 - val_dice_coef_gpu: 1.8449
# Epoch 140/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0117 - accuracy: 0.6231 - iou_gpu: 24.9819 - dice_coef_gpu: 1.9224 - val_loss: 0.9866 - val_accuracy: 0.6275 - val_iou_gpu: 20.2128 - val_dice_coef_gpu: 1.8433
# Epoch 141/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0126 - accuracy: 0.6243 - iou_gpu: 24.9686 - dice_coef_gpu: 1.9224 - val_loss: 1.9221 - val_accuracy: 0.6743 - val_iou_gpu: 18.3295 - val_dice_coef_gpu: 1.8319
# Epoch 142/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.1167 - accuracy: 0.5906 - iou_gpu: 24.2060 - dice_coef_gpu: 1.9200 - val_loss: 1.2684 - val_accuracy: 0.5727 - val_iou_gpu: 20.0590 - val_dice_coef_gpu: 1.8393
# Epoch 143/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0218 - accuracy: 0.5675 - iou_gpu: 24.8033 - dice_coef_gpu: 1.9217 - val_loss: 1.0228 - val_accuracy: 0.5997 - val_iou_gpu: 20.6357 - val_dice_coef_gpu: 1.8465
# Epoch 144/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0153 - accuracy: 0.5872 - iou_gpu: 24.9075 - dice_coef_gpu: 1.9221 - val_loss: 0.9958 - val_accuracy: 0.6157 - val_iou_gpu: 20.5006 - val_dice_coef_gpu: 1.8454
# Epoch 145/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0136 - accuracy: 0.5934 - iou_gpu: 24.9378 - dice_coef_gpu: 1.9222 - val_loss: 1.0429 - val_accuracy: 0.6297 - val_iou_gpu: 20.2897 - val_dice_coef_gpu: 1.8431
# Epoch 146/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0129 - accuracy: 0.5967 - iou_gpu: 24.9519 - dice_coef_gpu: 1.9221 - val_loss: 0.9996 - val_accuracy: 0.6254 - val_iou_gpu: 20.2277 - val_dice_coef_gpu: 1.8438
# Epoch 147/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0123 - accuracy: 0.6005 - iou_gpu: 24.9680 - dice_coef_gpu: 1.9224 - val_loss: 1.0726 - val_accuracy: 0.6364 - val_iou_gpu: 20.0770 - val_dice_coef_gpu: 1.8417
# Epoch 148/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0115 - accuracy: 0.6029 - iou_gpu: 24.9823 - dice_coef_gpu: 1.9224 - val_loss: 1.0342 - val_accuracy: 0.6372 - val_iou_gpu: 20.1770 - val_dice_coef_gpu: 1.8425
# Epoch 149/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0113 - accuracy: 0.6058 - iou_gpu: 24.9849 - dice_coef_gpu: 1.9224 - val_loss: 1.0529 - val_accuracy: 0.6416 - val_iou_gpu: 20.2626 - val_dice_coef_gpu: 1.8425
# Epoch 150/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0112 - accuracy: 0.6048 - iou_gpu: 24.9881 - dice_coef_gpu: 1.9223 - val_loss: 1.0357 - val_accuracy: 0.6393 - val_iou_gpu: 20.3742 - val_dice_coef_gpu: 1.8433
# Epoch 151/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0106 - accuracy: 0.6053 - iou_gpu: 24.9974 - dice_coef_gpu: 1.9224 - val_loss: 1.0411 - val_accuracy: 0.6370 - val_iou_gpu: 20.4199 - val_dice_coef_gpu: 1.8429
# Epoch 152/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0104 - accuracy: 0.6060 - iou_gpu: 25.0027 - dice_coef_gpu: 1.9225 - val_loss: 1.0154 - val_accuracy: 0.6366 - val_iou_gpu: 20.3302 - val_dice_coef_gpu: 1.8435
# Epoch 153/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0100 - accuracy: 0.6084 - iou_gpu: 25.0069 - dice_coef_gpu: 1.9224 - val_loss: 1.0375 - val_accuracy: 0.6415 - val_iou_gpu: 20.3429 - val_dice_coef_gpu: 1.8430
# Epoch 154/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0100 - accuracy: 0.6085 - iou_gpu: 25.0058 - dice_coef_gpu: 1.9223 - val_loss: 1.0255 - val_accuracy: 0.6390 - val_iou_gpu: 20.3216 - val_dice_coef_gpu: 1.8434
# Epoch 155/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0096 - accuracy: 0.6086 - iou_gpu: 25.0185 - dice_coef_gpu: 1.9226 - val_loss: 1.0614 - val_accuracy: 0.6412 - val_iou_gpu: 20.2103 - val_dice_coef_gpu: 1.8427
# Epoch 156/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0097 - accuracy: 0.6089 - iou_gpu: 25.0177 - dice_coef_gpu: 1.9223 - val_loss: 1.0766 - val_accuracy: 0.6408 - val_iou_gpu: 20.2005 - val_dice_coef_gpu: 1.8424
# Epoch 157/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0098 - accuracy: 0.6102 - iou_gpu: 25.0205 - dice_coef_gpu: 1.9225 - val_loss: 0.9746 - val_accuracy: 0.6381 - val_iou_gpu: 20.4855 - val_dice_coef_gpu: 1.8444
# Epoch 158/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0092 - accuracy: 0.6113 - iou_gpu: 25.0295 - dice_coef_gpu: 1.9227 - val_loss: 0.9993 - val_accuracy: 0.6448 - val_iou_gpu: 20.5264 - val_dice_coef_gpu: 1.8452
# Epoch 159/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0096 - accuracy: 0.6118 - iou_gpu: 25.0271 - dice_coef_gpu: 1.9227 - val_loss: 1.0015 - val_accuracy: 0.6356 - val_iou_gpu: 20.5615 - val_dice_coef_gpu: 1.8455
# Epoch 160/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0092 - accuracy: 0.6127 - iou_gpu: 25.0264 - dice_coef_gpu: 1.9224 - val_loss: 0.9518 - val_accuracy: 0.6423 - val_iou_gpu: 20.6901 - val_dice_coef_gpu: 1.8466
# Epoch 161/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0091 - accuracy: 0.6138 - iou_gpu: 25.0334 - dice_coef_gpu: 1.9226 - val_loss: 0.9707 - val_accuracy: 0.6416 - val_iou_gpu: 20.6166 - val_dice_coef_gpu: 1.8457
# Epoch 162/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0091 - accuracy: 0.6139 - iou_gpu: 25.0335 - dice_coef_gpu: 1.9225 - val_loss: 0.9905 - val_accuracy: 0.6390 - val_iou_gpu: 20.6279 - val_dice_coef_gpu: 1.8453
# Epoch 163/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0088 - accuracy: 0.6142 - iou_gpu: 25.0400 - dice_coef_gpu: 1.9226 - val_loss: 0.9867 - val_accuracy: 0.6424 - val_iou_gpu: 20.5711 - val_dice_coef_gpu: 1.8457
# Epoch 164/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0087 - accuracy: 0.6147 - iou_gpu: 25.0409 - dice_coef_gpu: 1.9225 - val_loss: 0.9809 - val_accuracy: 0.6335 - val_iou_gpu: 20.6348 - val_dice_coef_gpu: 1.8455
# Epoch 165/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0086 - accuracy: 0.6142 - iou_gpu: 25.0435 - dice_coef_gpu: 1.9226 - val_loss: 0.9904 - val_accuracy: 0.6446 - val_iou_gpu: 20.5622 - val_dice_coef_gpu: 1.8450
# Epoch 166/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0087 - accuracy: 0.6137 - iou_gpu: 25.0417 - dice_coef_gpu: 1.9225 - val_loss: 1.0038 - val_accuracy: 0.6389 - val_iou_gpu: 20.6979 - val_dice_coef_gpu: 1.8451
# Epoch 167/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0084 - accuracy: 0.6143 - iou_gpu: 25.0502 - dice_coef_gpu: 1.9226 - val_loss: 1.0017 - val_accuracy: 0.6458 - val_iou_gpu: 20.6841 - val_dice_coef_gpu: 1.8458
# Epoch 168/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0083 - accuracy: 0.6153 - iou_gpu: 25.0523 - dice_coef_gpu: 1.9227 - val_loss: 0.9866 - val_accuracy: 0.6410 - val_iou_gpu: 20.8541 - val_dice_coef_gpu: 1.8463
# Epoch 169/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0084 - accuracy: 0.6165 - iou_gpu: 25.0473 - dice_coef_gpu: 1.9226 - val_loss: 0.9842 - val_accuracy: 0.6445 - val_iou_gpu: 20.7075 - val_dice_coef_gpu: 1.8460
# Epoch 170/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0084 - accuracy: 0.6158 - iou_gpu: 25.0495 - dice_coef_gpu: 1.9225 - val_loss: 0.9663 - val_accuracy: 0.6383 - val_iou_gpu: 20.7102 - val_dice_coef_gpu: 1.8464
# Epoch 171/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0081 - accuracy: 0.6168 - iou_gpu: 25.0542 - dice_coef_gpu: 1.9227 - val_loss: 1.0074 - val_accuracy: 0.6382 - val_iou_gpu: 20.6374 - val_dice_coef_gpu: 1.8451
# Epoch 172/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0082 - accuracy: 0.6164 - iou_gpu: 25.0506 - dice_coef_gpu: 1.9224 - val_loss: 1.0174 - val_accuracy: 0.6497 - val_iou_gpu: 20.5199 - val_dice_coef_gpu: 1.8447
# Epoch 173/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0079 - accuracy: 0.6152 - iou_gpu: 25.0569 - dice_coef_gpu: 1.9224 - val_loss: 0.9654 - val_accuracy: 0.6468 - val_iou_gpu: 20.7327 - val_dice_coef_gpu: 1.8470
# Epoch 174/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0082 - accuracy: 0.6187 - iou_gpu: 25.0568 - dice_coef_gpu: 1.9226 - val_loss: 1.0121 - val_accuracy: 0.6456 - val_iou_gpu: 20.5008 - val_dice_coef_gpu: 1.8451
# Epoch 175/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0082 - accuracy: 0.6164 - iou_gpu: 25.0541 - dice_coef_gpu: 1.9225 - val_loss: 1.0440 - val_accuracy: 0.6472 - val_iou_gpu: 20.5963 - val_dice_coef_gpu: 1.8452
# Epoch 176/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0081 - accuracy: 0.6170 - iou_gpu: 25.0593 - dice_coef_gpu: 1.9227 - val_loss: 0.9931 - val_accuracy: 0.6459 - val_iou_gpu: 20.7187 - val_dice_coef_gpu: 1.8461
# Epoch 177/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0078 - accuracy: 0.6168 - iou_gpu: 25.0615 - dice_coef_gpu: 1.9226 - val_loss: 1.0406 - val_accuracy: 0.6477 - val_iou_gpu: 20.3588 - val_dice_coef_gpu: 1.8436
# Epoch 178/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0080 - accuracy: 0.6158 - iou_gpu: 25.0598 - dice_coef_gpu: 1.9226 - val_loss: 0.9816 - val_accuracy: 0.6483 - val_iou_gpu: 20.8438 - val_dice_coef_gpu: 1.8466
# Epoch 179/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0078 - accuracy: 0.6188 - iou_gpu: 25.0624 - dice_coef_gpu: 1.9227 - val_loss: 1.0142 - val_accuracy: 0.6423 - val_iou_gpu: 20.6410 - val_dice_coef_gpu: 1.8453
# Epoch 180/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0074 - accuracy: 0.6182 - iou_gpu: 25.0671 - dice_coef_gpu: 1.9224 - val_loss: 0.9552 - val_accuracy: 0.6372 - val_iou_gpu: 20.6076 - val_dice_coef_gpu: 1.8459
# Epoch 181/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0075 - accuracy: 0.6169 - iou_gpu: 25.0682 - dice_coef_gpu: 1.9228 - val_loss: 1.0443 - val_accuracy: 0.6481 - val_iou_gpu: 20.7193 - val_dice_coef_gpu: 1.8458
# Epoch 182/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0074 - accuracy: 0.6185 - iou_gpu: 25.0705 - dice_coef_gpu: 1.9227 - val_loss: 0.9973 - val_accuracy: 0.6381 - val_iou_gpu: 20.6240 - val_dice_coef_gpu: 1.8461
# Epoch 183/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0075 - accuracy: 0.6170 - iou_gpu: 25.0681 - dice_coef_gpu: 1.9226 - val_loss: 1.0261 - val_accuracy: 0.6476 - val_iou_gpu: 20.5780 - val_dice_coef_gpu: 1.8453
# Epoch 184/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0073 - accuracy: 0.6169 - iou_gpu: 25.0702 - dice_coef_gpu: 1.9225 - val_loss: 1.0135 - val_accuracy: 0.6414 - val_iou_gpu: 20.6402 - val_dice_coef_gpu: 1.8465
# Epoch 185/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0075 - accuracy: 0.6179 - iou_gpu: 25.0706 - dice_coef_gpu: 1.9227 - val_loss: 0.9923 - val_accuracy: 0.6313 - val_iou_gpu: 20.8246 - val_dice_coef_gpu: 1.8458
# Epoch 186/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0078 - accuracy: 0.6178 - iou_gpu: 25.0681 - dice_coef_gpu: 1.9227 - val_loss: 1.0346 - val_accuracy: 0.6417 - val_iou_gpu: 20.6617 - val_dice_coef_gpu: 1.8453
# Epoch 187/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0072 - accuracy: 0.6185 - iou_gpu: 25.0751 - dice_coef_gpu: 1.9227 - val_loss: 1.0597 - val_accuracy: 0.6461 - val_iou_gpu: 20.5210 - val_dice_coef_gpu: 1.8440
# Epoch 188/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0075 - accuracy: 0.6168 - iou_gpu: 25.0746 - dice_coef_gpu: 1.9227 - val_loss: 1.0580 - val_accuracy: 0.6404 - val_iou_gpu: 20.6854 - val_dice_coef_gpu: 1.8448
# Epoch 189/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0074 - accuracy: 0.6171 - iou_gpu: 25.0720 - dice_coef_gpu: 1.9227 - val_loss: 1.0457 - val_accuracy: 0.6337 - val_iou_gpu: 20.6533 - val_dice_coef_gpu: 1.8455
# Epoch 190/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0072 - accuracy: 0.6188 - iou_gpu: 25.0767 - dice_coef_gpu: 1.9227 - val_loss: 0.9736 - val_accuracy: 0.6387 - val_iou_gpu: 21.1165 - val_dice_coef_gpu: 1.8478
# Epoch 191/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0071 - accuracy: 0.6221 - iou_gpu: 25.0788 - dice_coef_gpu: 1.9227 - val_loss: 0.9962 - val_accuracy: 0.6481 - val_iou_gpu: 20.9156 - val_dice_coef_gpu: 1.8473
# Epoch 192/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0067 - accuracy: 0.6219 - iou_gpu: 25.0820 - dice_coef_gpu: 1.9228 - val_loss: 0.9423 - val_accuracy: 0.6389 - val_iou_gpu: 20.9982 - val_dice_coef_gpu: 1.8483
# Epoch 193/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0070 - accuracy: 0.6227 - iou_gpu: 25.0797 - dice_coef_gpu: 1.9225 - val_loss: 0.9823 - val_accuracy: 0.6396 - val_iou_gpu: 20.6479 - val_dice_coef_gpu: 1.8460
# Epoch 194/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0076 - accuracy: 0.6228 - iou_gpu: 25.0748 - dice_coef_gpu: 1.9225 - val_loss: 1.0794 - val_accuracy: 0.6343 - val_iou_gpu: 20.5933 - val_dice_coef_gpu: 1.8451
# Epoch 195/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0069 - accuracy: 0.6206 - iou_gpu: 25.0823 - dice_coef_gpu: 1.9227 - val_loss: 1.0555 - val_accuracy: 0.6460 - val_iou_gpu: 20.7617 - val_dice_coef_gpu: 1.8467
# Epoch 196/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0071 - accuracy: 0.6223 - iou_gpu: 25.0811 - dice_coef_gpu: 1.9227 - val_loss: 1.0275 - val_accuracy: 0.6417 - val_iou_gpu: 20.9831 - val_dice_coef_gpu: 1.8477
# Epoch 197/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0068 - accuracy: 0.6231 - iou_gpu: 25.0817 - dice_coef_gpu: 1.9227 - val_loss: 1.0652 - val_accuracy: 0.6373 - val_iou_gpu: 20.9624 - val_dice_coef_gpu: 1.8475
# Epoch 198/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0076 - accuracy: 0.6242 - iou_gpu: 25.0754 - dice_coef_gpu: 1.9226 - val_loss: 1.1040 - val_accuracy: 0.6349 - val_iou_gpu: 20.8831 - val_dice_coef_gpu: 1.8478
# Epoch 199/200
# 80/80 [==============================] - 20s 246ms/step - loss: 0.0079 - accuracy: 0.6184 - iou_gpu: 25.0729 - dice_coef_gpu: 1.9226 - val_loss: 1.0538 - val_accuracy: 0.6355 - val_iou_gpu: 20.8845 - val_dice_coef_gpu: 1.8484
# Epoch 200/200
# 80/80 [==============================] - 20s 247ms/step - loss: 0.0071 - accuracy: 0.6193 - iou_gpu: 25.0800 - dice_coef_gpu: 1.9223 - val_loss: 1.0377 - val_accuracy: 0.6476 - val_iou_gpu: 21.1059 - val_dice_coef_gpu: 1.8492

# %% [markdown]
# ## Plot

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

val_dice = history.history['val_dice_coef_gpu']

# %%
plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.1))

plt.plot(train_loss, 'r', label='Train loss')
plt.plot(val_loss, 'b', label='Validation loss')

plt.legend()

# %%
train_dice = history.history['dice_coef_gpu']
val_dice = history.history['val_dice_coef_gpu']

# %%
plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.3))

plt.plot(train_dice, 'r', label='Train Dice coefficient')
plt.plot(val_dice, 'b', label='Validation Dice coefficient')

plt.legend()

# %% [markdown]
# ---
# # Test

# %%
test_data.shape
# Out:
# (1000, 128, 128, 3)

# %%
# test_data, test_label

predict_result = model.predict(test_data)

# %%
q = 300

plt.figure(figsize = (15, 15))

plt.subplot(231)
plt.imshow(test_data[q])

plt.subplot(232)
plt.imshow(test_label[q])

plt.subplot(233)
plt.imshow(predict_result[q])


#print(iou_gpu(test_label[q], predict_result[q]))
