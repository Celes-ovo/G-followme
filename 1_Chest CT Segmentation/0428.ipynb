# %% [markdown]
# # 1. Model 구현

# %%
import cv2, numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
tf.version
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\GC\\anaconda3\\envs\\sangmin_env\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
# Dice coefficient, IoU Metric

def iou(y_true, y_pred):
    y_true_f = np.ndarray.flatten(y_true)
    y_pred_f = np.ndarray.flatten(y_pred)

    intersection = np.sum(y_true_f * y_pred_f)
    #return (intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) - intersection + 1)
    return (intersection + np.finfo(np.float).eps) / (np.sum(y_true_f) + np.sum(y_pred_f) - intersection + np.finfo(np.float).eps)

def dice_coef(y_true, y_pred):
    y_true_f = np.ndarray.flatten(y_true)
    y_pred_f = np.ndarray.flatten(y_pred)

    intersection = np.sum(y_true_f * y_pred_f)
    #return (2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1)
    return (2. * intersection + np.finfo(np.float).eps) / (np.sum(y_true_f) + np.sum(y_pred_f) + np.finfo(np.float).eps)

# %%
# Dice coefficient, IoU Metric

from tensorflow.keras import backend as K

def iou_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + K.epsilon())
	
def dice_coef_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %%
import keras
from keras import models, layers


def conv_3x3_relu(x, n):
    x = layers.Conv2D(n, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(max_value=None, negative_slope=0, threshold=0)(x)

    return x



def Unet(a, b, c, d):
    # a = input_size
    # b = 처음에 몇 채널로 시작할지
    # c = output channel의 개수.
    # d = activation function

    input = layers.Input(a)


    #Encoder

    x = conv_3x3_relu(input, b)
    down1 = conv_3x3_relu(x, b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down1)


    x = conv_3x3_relu(x, 2*b)
    down2 = conv_3x3_relu(x, 2*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down2)


    x = conv_3x3_relu(x, 4*b)
    down3 = conv_3x3_relu(x, 4*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down3)


    x = conv_3x3_relu(x, 8*b)
    down4 = conv_3x3_relu(x, 8*b)
    drop1 = layers.Dropout(0.3)(down4)
    x = layers.MaxPool2D(pool_size=(2, 2))(drop1)




    # Bottleneck

    x = conv_3x3_relu(x, 16*b)
    x = conv_3x3_relu(x, 16*b)
    drop2 = layers.Dropout(0.3)(x)




    # Decoder

    up1 = layers.Conv2DTranspose(8*b, (2, 2), strides=(2, 2))(drop2)
    merge1 = layers.concatenate([down4, up1], axis=3)
    x = conv_3x3_relu(merge1, 8*b)
    x = conv_3x3_relu(x, 8*b)
    x = conv_3x3_relu(x, 8*b)


    up2 = layers.Conv2DTranspose(4*b, (2, 2), strides=(2, 2))(x)
    merge2 = layers.concatenate([down3, up2], axis=3)
    x = conv_3x3_relu(merge2, 4*b)
    x = conv_3x3_relu(x, 4*b) 
    x = conv_3x3_relu(x, 4*b)


    up3 = layers.Conv2DTranspose(2*b, (2, 2), strides=(2, 2))(x)
    merge3 = layers.concatenate([down2, up3], axis=3)
    x = conv_3x3_relu(merge3, 2*b)
    x = conv_3x3_relu(x, 2*b) 
    x = conv_3x3_relu(x, 2*b)


    up4 = layers.Conv2DTranspose(b, (2, 2), strides=(2, 2))(x)
    merge4 = layers.concatenate([down1, up4], axis=3)
    x = conv_3x3_relu(merge4, b)
    x = conv_3x3_relu(x, b) 

    output = layers.Conv2D(c, (1, 1),name = 'result',activation = d)(x)

    Unet_model = models.Model(inputs=input, outputs=output)


    return Unet_model

# %% [markdown]
# ---
#
# ```# a = input_size
#     # b = 처음에 몇 채널로 시작할지
#     # c = output channel의 개수.
#     # d = activation function```

# %%
model = Unet((128, 128, 3), 32, 3, 'softmax')

# %% [markdown]
# # 2. Data load

# %%
import glob

data = glob.glob('.\\Data\\Chest CT Segmentation\\image\\image\\*.jpg')
label = glob.glob('.\\Data\\Chest CT Segmentation\\masks\\masks\\*.jpg')

# %%
print(len(data), len(label))
# Out:
# 16708 16708

# %%
def get_img(fstr):
    """
    jpg, png등의 영상을 읽어들임.
    numpy ndarray형으로 읽어들임.
    """
    img = cv2.imread(fstr)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (128, 128))
    img = img/255.0
    #print(img.shape, img.dtype, np.max(img))
    return img

# %%
train_data = []
train_label = []

val_data = []
val_label = []

test_data = []
test_label = []


for i in range(8000):
    train_x = get_img(data[i])
    train_y = get_img(label[i])
    
    train_data.append(train_x)
    train_label.append(train_y)
    
    
for i in range(2000):
    val_x = get_img(data[i+5600])
    val_y = get_img(label[i+5600])
    
    val_data.append(val_x)
    val_label.append(val_y)
    

for i in range(1000):
    val_x = get_img(data[i+7000])
    val_y = get_img(label[i+7000])
    
    test_data.append(val_x)
    test_label.append(val_y)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(221)
plt.imshow(train_data[15])

plt.subplot(222)
plt.imshow(train_label[15])

# %%
np.max(train_label[200])
# Out:
# 1.0

# %%
train_data = np.array(train_data)
train_label = np.array(train_label)

val_data = np.array(val_data)
val_label = np.array(val_label)

test_data = np.array(test_data)
test_label = np.array(test_label)


print(train_data.shape, train_label.shape, val_data.shape, val_label.shape, test_data.shape, test_label.shape, end='\n')
# Out:
# (8000, 128, 128, 3) (8000, 128, 128, 3) (2000, 128, 128, 3) (2000, 128, 128, 3) (1000, 128, 128, 3) (1000, 128, 128, 3)

# %%
train_data.shape
# Out:
# (8000, 128, 128, 3)

# %%
np.save('./Data/Chest CT Segmentation/train_x.npy', train_data)
np.save('./Data/Chest CT Segmentation/train_y.npy', train_label)

np.save('./Data/Chest CT Segmentation/val_x.npy', val_data)
np.save('./Data/Chest CT Segmentation/val_y.npy', val_label)

np.save('./Data/Chest CT Segmentation/test_x.npy', test_data)
np.save('./Data/Chest CT Segmentation/test_y.npy', test_label)

# %%
#model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy, metrics='val_loss')
model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics = ('accuracy', dice_coef_gpu))

# %%
history = model.fit(train_data, train_label, epochs = 200, batch_size = 100 ,validation_data = (val_data, val_label))
# Out:
# Epoch 1/200
#  2/80 [..............................] - ETA: 9s - loss: 0.1384 - accuracy: 0.3439 - dice_coef_gpu: 0.0704WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0170s vs `on_train_batch_end` time: 0.2121s). Check your callbacks.
# 80/80 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.3744 - dice_coef_gpu: 0.1690WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0080s vs `on_test_batch_end` time: 0.0589s). Check your callbacks.
# 80/80 [==============================] - 20s 250ms/step - loss: 0.0225 - accuracy: 0.3744 - dice_coef_gpu: 0.1690 - val_loss: 0.0486 - val_accuracy: 0.1150 - val_dice_coef_gpu: 0.1649
# Epoch 2/200
# 80/80 [==============================] - 19s 241ms/step - loss: 0.0096 - accuracy: 0.4114 - dice_coef_gpu: 0.1826 - val_loss: 0.0465 - val_accuracy: 0.1118 - val_dice_coef_gpu: 0.1597
# Epoch 3/200
# 80/80 [==============================] - 19s 242ms/step - loss: 0.0074 - accuracy: 0.4193 - dice_coef_gpu: 0.1847 - val_loss: 0.0328 - val_accuracy: 0.1597 - val_dice_coef_gpu: 0.1697
# Epoch 4/200
# 80/80 [==============================] - 19s 243ms/step - loss: 0.0062 - accuracy: 0.4226 - dice_coef_gpu: 0.1859 - val_loss: 0.0370 - val_accuracy: 0.1454 - val_dice_coef_gpu: 0.1587
# Epoch 5/200
# 80/80 [==============================] - 20s 244ms/step - loss: 0.0060 - accuracy: 0.4220 - dice_coef_gpu: 0.1861 - val_loss: 0.0151 - val_accuracy: 0.3472 - val_dice_coef_gpu: 0.1823
# Epoch 6/200
# 80/80 [==============================] - 20s 245ms/step - loss: 0.0065 - accuracy: 0.4175 - dice_coef_gpu: 0.1856 - val_loss: 0.0390 - val_accuracy: 0.3514 - val_dice_coef_gpu: 0.1786
# Epoch 7/200
# 80/80 [==============================] - 20s 245ms/step - loss: 0.0072 - accuracy: 0.4220 - dice_coef_gpu: 0.1849 - val_loss: 0.0076 - val_accuracy: 0.2879 - val_dice_coef_gpu: 0.1902
# Epoch 8/200
# 80/80 [==============================] - 20s 253ms/step - loss: 0.0056 - accuracy: 0.4240 - dice_coef_gpu: 0.1864 - val_loss: 0.0061 - val_accuracy: 0.3575 - val_dice_coef_gpu: 0.1900
# Epoch 9/200
# 80/80 [==============================] - 20s 254ms/step - loss: 0.0055 - accuracy: 0.4142 - dice_coef_gpu: 0.1865 - val_loss: 0.0054 - val_accuracy: 0.3963 - val_dice_coef_gpu: 0.1902
# Epoch 10/200
# 80/80 [==============================] - 20s 254ms/step - loss: 0.0052 - accuracy: 0.4057 - dice_coef_gpu: 0.1867 - val_loss: 0.0053 - val_accuracy: 0.4102 - val_dice_coef_gpu: 0.1901
# Epoch 11/200
# 80/80 [==============================] - 20s 251ms/step - loss: 0.0051 - accuracy: 0.3928 - dice_coef_gpu: 0.1868 - val_loss: 0.0053 - val_accuracy: 0.3889 - val_dice_coef_gpu: 0.1898
# Epoch 12/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0050 - accuracy: 0.3875 - dice_coef_gpu: 0.1868 - val_loss: 0.0052 - val_accuracy: 0.4034 - val_dice_coef_gpu: 0.1902
# Epoch 13/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0050 - accuracy: 0.3876 - dice_coef_gpu: 0.1869 - val_loss: 0.0051 - val_accuracy: 0.3820 - val_dice_coef_gpu: 0.1903
# Epoch 14/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0049 - accuracy: 0.3834 - dice_coef_gpu: 0.1869 - val_loss: 0.0051 - val_accuracy: 0.4019 - val_dice_coef_gpu: 0.1900
# Epoch 15/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0049 - accuracy: 0.3843 - dice_coef_gpu: 0.1870 - val_loss: 0.0051 - val_accuracy: 0.4215 - val_dice_coef_gpu: 0.1903
# Epoch 16/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0049 - accuracy: 0.3873 - dice_coef_gpu: 0.1869 - val_loss: 0.0050 - val_accuracy: 0.4138 - val_dice_coef_gpu: 0.1905
# Epoch 17/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0049 - accuracy: 0.3892 - dice_coef_gpu: 0.1869 - val_loss: 0.0050 - val_accuracy: 0.3981 - val_dice_coef_gpu: 0.1905
# Epoch 18/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0048 - accuracy: 0.3842 - dice_coef_gpu: 0.1870 - val_loss: 0.0050 - val_accuracy: 0.4018 - val_dice_coef_gpu: 0.1902
# Epoch 19/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0047 - accuracy: 0.3830 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3894 - val_dice_coef_gpu: 0.1903
# Epoch 20/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0047 - accuracy: 0.3818 - dice_coef_gpu: 0.1870 - val_loss: 0.0049 - val_accuracy: 0.4015 - val_dice_coef_gpu: 0.1903
# Epoch 21/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0047 - accuracy: 0.3834 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3753 - val_dice_coef_gpu: 0.1904
# Epoch 22/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0047 - accuracy: 0.3880 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3868 - val_dice_coef_gpu: 0.1902
# Epoch 23/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3829 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3679 - val_dice_coef_gpu: 0.1903
# Epoch 24/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3845 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3944 - val_dice_coef_gpu: 0.1903
# Epoch 25/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3828 - dice_coef_gpu: 0.1871 - val_loss: 0.0048 - val_accuracy: 0.3964 - val_dice_coef_gpu: 0.1906
# Epoch 26/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3843 - dice_coef_gpu: 0.1871 - val_loss: 0.0048 - val_accuracy: 0.3936 - val_dice_coef_gpu: 0.1904
# Epoch 27/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3832 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3941 - val_dice_coef_gpu: 0.1903
# Epoch 28/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0077 - accuracy: 0.3847 - dice_coef_gpu: 0.1843 - val_loss: 0.1616 - val_accuracy: 0.1359 - val_dice_coef_gpu: 0.1662
# Epoch 29/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0059 - accuracy: 0.3745 - dice_coef_gpu: 0.1862 - val_loss: 0.0095 - val_accuracy: 0.2779 - val_dice_coef_gpu: 0.1896
# Epoch 30/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0052 - accuracy: 0.3632 - dice_coef_gpu: 0.1867 - val_loss: 0.0053 - val_accuracy: 0.3268 - val_dice_coef_gpu: 0.1905
# Epoch 31/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0050 - accuracy: 0.3555 - dice_coef_gpu: 0.1869 - val_loss: 0.0053 - val_accuracy: 0.3341 - val_dice_coef_gpu: 0.1902
# Epoch 32/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0049 - accuracy: 0.3536 - dice_coef_gpu: 0.1870 - val_loss: 0.0053 - val_accuracy: 0.3608 - val_dice_coef_gpu: 0.1894
# Epoch 33/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0048 - accuracy: 0.3521 - dice_coef_gpu: 0.1870 - val_loss: 0.0052 - val_accuracy: 0.3739 - val_dice_coef_gpu: 0.1896
# Epoch 34/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0049 - accuracy: 0.3589 - dice_coef_gpu: 0.1869 - val_loss: 0.0051 - val_accuracy: 0.3930 - val_dice_coef_gpu: 0.1898
# Epoch 35/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0047 - accuracy: 0.3594 - dice_coef_gpu: 0.1870 - val_loss: 0.0050 - val_accuracy: 0.3637 - val_dice_coef_gpu: 0.1900
# Epoch 36/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0047 - accuracy: 0.3588 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3745 - val_dice_coef_gpu: 0.1903
# Epoch 37/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3579 - dice_coef_gpu: 0.1872 - val_loss: 0.0049 - val_accuracy: 0.3720 - val_dice_coef_gpu: 0.1903
# Epoch 38/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3611 - dice_coef_gpu: 0.1871 - val_loss: 0.0049 - val_accuracy: 0.3674 - val_dice_coef_gpu: 0.1902
# Epoch 39/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3603 - dice_coef_gpu: 0.1871 - val_loss: 0.0048 - val_accuracy: 0.3757 - val_dice_coef_gpu: 0.1905
# Epoch 40/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3609 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3863 - val_dice_coef_gpu: 0.1902
# Epoch 41/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3595 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3786 - val_dice_coef_gpu: 0.1906
# Epoch 42/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3590 - dice_coef_gpu: 0.1871 - val_loss: 0.0048 - val_accuracy: 0.3785 - val_dice_coef_gpu: 0.1904
# Epoch 43/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3607 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3952 - val_dice_coef_gpu: 0.1906
# Epoch 44/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3625 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3675 - val_dice_coef_gpu: 0.1904
# Epoch 45/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3597 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3781 - val_dice_coef_gpu: 0.1905
# Epoch 46/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3595 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3873 - val_dice_coef_gpu: 0.1905
# Epoch 47/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3602 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3773 - val_dice_coef_gpu: 0.1905
# Epoch 48/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3597 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3901 - val_dice_coef_gpu: 0.1906
# Epoch 49/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3621 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.4060 - val_dice_coef_gpu: 0.1907
# Epoch 50/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3670 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3765 - val_dice_coef_gpu: 0.1906
# Epoch 51/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0045 - accuracy: 0.3641 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3841 - val_dice_coef_gpu: 0.1906
# Epoch 52/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3639 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3836 - val_dice_coef_gpu: 0.1904
# Epoch 53/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3630 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3580 - val_dice_coef_gpu: 0.1907
# Epoch 54/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3608 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3748 - val_dice_coef_gpu: 0.1906
# Epoch 55/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3611 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3793 - val_dice_coef_gpu: 0.1907
# Epoch 56/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3575 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3850 - val_dice_coef_gpu: 0.1908
# Epoch 57/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3609 - dice_coef_gpu: 0.1873 - val_loss: 0.0047 - val_accuracy: 0.3790 - val_dice_coef_gpu: 0.1906
# Epoch 58/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3611 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3636 - val_dice_coef_gpu: 0.1907
# Epoch 59/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3579 - dice_coef_gpu: 0.1872 - val_loss: 0.0046 - val_accuracy: 0.3578 - val_dice_coef_gpu: 0.1905
# Epoch 60/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3583 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3754 - val_dice_coef_gpu: 0.1906
# Epoch 61/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3608 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3540 - val_dice_coef_gpu: 0.1908
# Epoch 62/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3586 - dice_coef_gpu: 0.1872 - val_loss: 0.0046 - val_accuracy: 0.3519 - val_dice_coef_gpu: 0.1906
# Epoch 63/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3601 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3650 - val_dice_coef_gpu: 0.1907
# Epoch 64/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3594 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3685 - val_dice_coef_gpu: 0.1906
# Epoch 65/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3574 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3720 - val_dice_coef_gpu: 0.1905
# Epoch 66/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0068 - accuracy: 0.3513 - dice_coef_gpu: 0.1853 - val_loss: 0.0967 - val_accuracy: 0.2035 - val_dice_coef_gpu: 0.1820
# Epoch 67/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0061 - accuracy: 0.3635 - dice_coef_gpu: 0.1859 - val_loss: 0.0138 - val_accuracy: 0.2457 - val_dice_coef_gpu: 0.1867
# Epoch 68/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0052 - accuracy: 0.3531 - dice_coef_gpu: 0.1868 - val_loss: 0.0051 - val_accuracy: 0.2910 - val_dice_coef_gpu: 0.1903
# Epoch 69/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0048 - accuracy: 0.3435 - dice_coef_gpu: 0.1870 - val_loss: 0.0052 - val_accuracy: 0.3246 - val_dice_coef_gpu: 0.1896
# Epoch 70/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0047 - accuracy: 0.3428 - dice_coef_gpu: 0.1871 - val_loss: 0.0051 - val_accuracy: 0.3430 - val_dice_coef_gpu: 0.1896
# Epoch 71/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3411 - dice_coef_gpu: 0.1872 - val_loss: 0.0050 - val_accuracy: 0.3469 - val_dice_coef_gpu: 0.1899
# Epoch 72/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0046 - accuracy: 0.3424 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3473 - val_dice_coef_gpu: 0.1901
# Epoch 73/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3418 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3511 - val_dice_coef_gpu: 0.1902
# Epoch 74/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3438 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3505 - val_dice_coef_gpu: 0.1903
# Epoch 75/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3420 - dice_coef_gpu: 0.1872 - val_loss: 0.0048 - val_accuracy: 0.3648 - val_dice_coef_gpu: 0.1902
# Epoch 76/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0045 - accuracy: 0.3458 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3573 - val_dice_coef_gpu: 0.1904
# Epoch 77/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3441 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3549 - val_dice_coef_gpu: 0.1904
# Epoch 78/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3455 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3505 - val_dice_coef_gpu: 0.1905
# Epoch 79/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3442 - dice_coef_gpu: 0.1873 - val_loss: 0.0047 - val_accuracy: 0.3588 - val_dice_coef_gpu: 0.1906
# Epoch 80/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3434 - dice_coef_gpu: 0.1872 - val_loss: 0.0047 - val_accuracy: 0.3540 - val_dice_coef_gpu: 0.1907
# Epoch 81/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3428 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3596 - val_dice_coef_gpu: 0.1906
# Epoch 82/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3460 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3624 - val_dice_coef_gpu: 0.1906
# Epoch 83/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3437 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3540 - val_dice_coef_gpu: 0.1906
# Epoch 84/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3424 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3531 - val_dice_coef_gpu: 0.1906
# Epoch 85/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3428 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3520 - val_dice_coef_gpu: 0.1906
# Epoch 86/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3390 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3538 - val_dice_coef_gpu: 0.1907
# Epoch 87/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3411 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3606 - val_dice_coef_gpu: 0.1907
# Epoch 88/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3393 - dice_coef_gpu: 0.1873 - val_loss: 0.0047 - val_accuracy: 0.3442 - val_dice_coef_gpu: 0.1905
# Epoch 89/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3376 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3357 - val_dice_coef_gpu: 0.1906
# Epoch 90/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3365 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3522 - val_dice_coef_gpu: 0.1906
# Epoch 91/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3369 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3458 - val_dice_coef_gpu: 0.1906
# Epoch 92/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3372 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3518 - val_dice_coef_gpu: 0.1908
# Epoch 93/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3381 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3524 - val_dice_coef_gpu: 0.1907
# Epoch 94/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3384 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3406 - val_dice_coef_gpu: 0.1907
# Epoch 95/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3378 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3476 - val_dice_coef_gpu: 0.1907
# Epoch 96/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3424 - dice_coef_gpu: 0.1873 - val_loss: 0.0047 - val_accuracy: 0.3881 - val_dice_coef_gpu: 0.1909
# Epoch 97/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3422 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3424 - val_dice_coef_gpu: 0.1908
# Epoch 98/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3389 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3411 - val_dice_coef_gpu: 0.1907
# Epoch 99/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3376 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3381 - val_dice_coef_gpu: 0.1908
# Epoch 100/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3353 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3536 - val_dice_coef_gpu: 0.1907
# Epoch 101/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3332 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3312 - val_dice_coef_gpu: 0.1907
# Epoch 102/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3317 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3601 - val_dice_coef_gpu: 0.1906
# Epoch 103/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3332 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3322 - val_dice_coef_gpu: 0.1905
# Epoch 104/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3332 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3375 - val_dice_coef_gpu: 0.1907
# Epoch 105/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3329 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3398 - val_dice_coef_gpu: 0.1907
# Epoch 106/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3325 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3255 - val_dice_coef_gpu: 0.1908
# Epoch 107/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3316 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3474 - val_dice_coef_gpu: 0.1908
# Epoch 108/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3282 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3268 - val_dice_coef_gpu: 0.1908
# Epoch 109/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3306 - dice_coef_gpu: 0.1873 - val_loss: 0.0046 - val_accuracy: 0.3379 - val_dice_coef_gpu: 0.1906
# Epoch 110/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3297 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3492 - val_dice_coef_gpu: 0.1908
# Epoch 111/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3298 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3484 - val_dice_coef_gpu: 0.1907
# Epoch 112/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3298 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3508 - val_dice_coef_gpu: 0.1906
# Epoch 113/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3279 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3319 - val_dice_coef_gpu: 0.1907
# Epoch 114/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3280 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3240 - val_dice_coef_gpu: 0.1908
# Epoch 115/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3301 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3374 - val_dice_coef_gpu: 0.1907
# Epoch 116/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3267 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3192 - val_dice_coef_gpu: 0.1908
# Epoch 117/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3259 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3440 - val_dice_coef_gpu: 0.1906
# Epoch 118/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3267 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3235 - val_dice_coef_gpu: 0.1907
# Epoch 119/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3243 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3330 - val_dice_coef_gpu: 0.1907
# Epoch 120/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3250 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3238 - val_dice_coef_gpu: 0.1907
# Epoch 121/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3249 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3290 - val_dice_coef_gpu: 0.1907
# Epoch 122/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3238 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3264 - val_dice_coef_gpu: 0.1907
# Epoch 123/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3281 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3607 - val_dice_coef_gpu: 0.1908
# Epoch 124/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3245 - dice_coef_gpu: 0.1874 - val_loss: 0.0046 - val_accuracy: 0.3258 - val_dice_coef_gpu: 0.1907
# Epoch 125/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0044 - accuracy: 0.3216 - dice_coef_gpu: 0.1873 - val_loss: 0.0047 - val_accuracy: 0.3508 - val_dice_coef_gpu: 0.1906
# Epoch 126/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0043 - accuracy: 0.3192 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3217 - val_dice_coef_gpu: 0.1905
# Epoch 127/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3181 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3176 - val_dice_coef_gpu: 0.1907
# Epoch 128/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3183 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3279 - val_dice_coef_gpu: 0.1907
# Epoch 129/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3181 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3179 - val_dice_coef_gpu: 0.1908
# Epoch 130/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3182 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3323 - val_dice_coef_gpu: 0.1908
# Epoch 131/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3165 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3112 - val_dice_coef_gpu: 0.1908
# Epoch 132/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3178 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3341 - val_dice_coef_gpu: 0.1906
# Epoch 133/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3169 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3316 - val_dice_coef_gpu: 0.1908
# Epoch 134/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3195 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3287 - val_dice_coef_gpu: 0.1907
# Epoch 135/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3180 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3278 - val_dice_coef_gpu: 0.1908
# Epoch 136/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3163 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3362 - val_dice_coef_gpu: 0.1908
# Epoch 137/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3162 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3164 - val_dice_coef_gpu: 0.1909
# Epoch 138/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3148 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3306 - val_dice_coef_gpu: 0.1907
# Epoch 139/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3139 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3266 - val_dice_coef_gpu: 0.1908
# Epoch 140/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3142 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3320 - val_dice_coef_gpu: 0.1908
# Epoch 141/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3154 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3155 - val_dice_coef_gpu: 0.1908
# Epoch 142/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3132 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3089 - val_dice_coef_gpu: 0.1908
# Epoch 143/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3117 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3196 - val_dice_coef_gpu: 0.1908
# Epoch 144/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3105 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3178 - val_dice_coef_gpu: 0.1908
# Epoch 145/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3110 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3184 - val_dice_coef_gpu: 0.1907
# Epoch 146/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3114 - dice_coef_gpu: 0.1873 - val_loss: 0.0044 - val_accuracy: 0.3298 - val_dice_coef_gpu: 0.1908
# Epoch 147/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3121 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3297 - val_dice_coef_gpu: 0.1908
# Epoch 148/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3122 - dice_coef_gpu: 0.1873 - val_loss: 0.0045 - val_accuracy: 0.3189 - val_dice_coef_gpu: 0.1907
# Epoch 149/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3097 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3138 - val_dice_coef_gpu: 0.1907
# Epoch 150/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3098 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3161 - val_dice_coef_gpu: 0.1908
# Epoch 151/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3094 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3242 - val_dice_coef_gpu: 0.1908
# Epoch 152/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3085 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3147 - val_dice_coef_gpu: 0.1908
# Epoch 153/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3086 - dice_coef_gpu: 0.1874 - val_loss: 0.0045 - val_accuracy: 0.3311 - val_dice_coef_gpu: 0.1907
# Epoch 154/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0042 - accuracy: 0.3090 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3171 - val_dice_coef_gpu: 0.1908
# Epoch 155/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3091 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3266 - val_dice_coef_gpu: 0.1908
# Epoch 156/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3103 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3290 - val_dice_coef_gpu: 0.1908
# Epoch 157/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3107 - dice_coef_gpu: 0.1873 - val_loss: 0.0044 - val_accuracy: 0.3134 - val_dice_coef_gpu: 0.1908
# Epoch 158/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3071 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3074 - val_dice_coef_gpu: 0.1907
# Epoch 159/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3069 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3149 - val_dice_coef_gpu: 0.1908
# Epoch 160/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3073 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3144 - val_dice_coef_gpu: 0.1909
# Epoch 161/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0042 - accuracy: 0.3070 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3176 - val_dice_coef_gpu: 0.1908
# Epoch 162/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3066 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3232 - val_dice_coef_gpu: 0.1907
# Epoch 163/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3060 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3143 - val_dice_coef_gpu: 0.1908
# Epoch 164/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3064 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3148 - val_dice_coef_gpu: 0.1908
# Epoch 165/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3080 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3213 - val_dice_coef_gpu: 0.1908
# Epoch 166/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3065 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3185 - val_dice_coef_gpu: 0.1909
# Epoch 167/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3068 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3166 - val_dice_coef_gpu: 0.1908
# Epoch 168/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3077 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3200 - val_dice_coef_gpu: 0.1909
# Epoch 169/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3063 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3067 - val_dice_coef_gpu: 0.1907
# Epoch 170/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3060 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3057 - val_dice_coef_gpu: 0.1909
# Epoch 171/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3057 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3179 - val_dice_coef_gpu: 0.1908
# Epoch 172/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3051 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3230 - val_dice_coef_gpu: 0.1908
# Epoch 173/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3052 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3181 - val_dice_coef_gpu: 0.1908
# Epoch 174/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3058 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3124 - val_dice_coef_gpu: 0.1908
# Epoch 175/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3049 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3116 - val_dice_coef_gpu: 0.1908
# Epoch 176/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3041 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3296 - val_dice_coef_gpu: 0.1908
# Epoch 177/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3056 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3147 - val_dice_coef_gpu: 0.1909
# Epoch 178/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3046 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3161 - val_dice_coef_gpu: 0.1909
# Epoch 179/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3035 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3001 - val_dice_coef_gpu: 0.1907
# Epoch 180/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0041 - accuracy: 0.3017 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3122 - val_dice_coef_gpu: 0.1907
# Epoch 181/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3046 - dice_coef_gpu: 0.1875 - val_loss: 0.0044 - val_accuracy: 0.3064 - val_dice_coef_gpu: 0.1908
# Epoch 182/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0041 - accuracy: 0.3020 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3186 - val_dice_coef_gpu: 0.1908
# Epoch 183/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3012 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3290 - val_dice_coef_gpu: 0.1908
# Epoch 184/200
# 80/80 [==============================] - 20s 249ms/step - loss: 0.0041 - accuracy: 0.3030 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.2969 - val_dice_coef_gpu: 0.1908
# Epoch 185/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3027 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3160 - val_dice_coef_gpu: 0.1909
# Epoch 186/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3007 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3193 - val_dice_coef_gpu: 0.1909
# Epoch 187/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3022 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3174 - val_dice_coef_gpu: 0.1909
# Epoch 188/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3024 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3080 - val_dice_coef_gpu: 0.1908
# Epoch 189/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3019 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3030 - val_dice_coef_gpu: 0.1909
# Epoch 190/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3023 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3121 - val_dice_coef_gpu: 0.1908
# Epoch 191/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3009 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3073 - val_dice_coef_gpu: 0.1907
# Epoch 192/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2996 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3061 - val_dice_coef_gpu: 0.1909
# Epoch 193/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2996 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3107 - val_dice_coef_gpu: 0.1908
# Epoch 194/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.3004 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3114 - val_dice_coef_gpu: 0.1909
# Epoch 195/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2989 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3005 - val_dice_coef_gpu: 0.1907
# Epoch 196/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2990 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3071 - val_dice_coef_gpu: 0.1909
# Epoch 197/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2961 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3117 - val_dice_coef_gpu: 0.1908
# Epoch 198/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2971 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3122 - val_dice_coef_gpu: 0.1908
# Epoch 199/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2966 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.3009 - val_dice_coef_gpu: 0.1909
# Epoch 200/200
# 80/80 [==============================] - 20s 248ms/step - loss: 0.0041 - accuracy: 0.2965 - dice_coef_gpu: 0.1874 - val_loss: 0.0044 - val_accuracy: 0.2994 - val_dice_coef_gpu: 0.1908

# %% [markdown]
# ## Plot

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize = (10, 10))
plt.ylim((0, 0.1))

plt.plot(train_loss, 'r')
plt.plot(val_loss, 'b')

# %% [markdown]
# ---
# # Test

# %%
test_data.shape
# Out:
# (1000, 128, 128, 3)

# %%
# test_data, test_label

predict_result = model.predict(test_data)

# %%
q = 500

plt.figure(figsize = (15, 15))

plt.subplot(231)
plt.imshow(test_data[q])

plt.subplot(232)
plt.imshow(test_label[q])

plt.subplot(233)
plt.imshow(predict_result[q])

# %% [markdown]
# ---
# ## Model weight save

# %%
import datetime as dt

time_now = dt.datetime.now()
print(time_now.date())
# Out:
# 2022-04-28

# %%
model.save('./weight/%s_model.h5' % time_now.date())
