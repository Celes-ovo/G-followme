# %% [markdown]
# # 1. Model 구현

# %%
import cv2, numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
tf.version
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\GC\\anaconda3\\envs\\sangmin_env\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
# Dice coefficient, IoU Metric

from tensorflow.keras import backend as K

def iou_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + K.epsilon())
	
def dice_coef_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %%
import keras
from keras import models, layers


def conv_3x3_relu(x, n):
    x = layers.Conv2D(n, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(max_value=None, negative_slope=0, threshold=0)(x)

    return x



def Unet(a, b, c, d):
    # a = input_size
    # b = 처음에 몇 채널로 시작할지
    # c = output channel의 개수.
    # d = activation function

    input = layers.Input(a)


    #Encoder

    x = conv_3x3_relu(input, b)
    down1 = conv_3x3_relu(x, b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down1)


    x = conv_3x3_relu(x, 2*b)
    down2 = conv_3x3_relu(x, 2*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down2)


    x = conv_3x3_relu(x, 4*b)
    down3 = conv_3x3_relu(x, 4*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down3)


    x = conv_3x3_relu(x, 8*b)
    down4 = conv_3x3_relu(x, 8*b)
    drop1 = layers.Dropout(0.3)(down4)
    x = layers.MaxPool2D(pool_size=(2, 2))(drop1)




    # Bottleneck

    x = conv_3x3_relu(x, 16*b)
    x = conv_3x3_relu(x, 16*b)
    drop2 = layers.Dropout(0.3)(x)




    # Decoder

    up1 = layers.Conv2DTranspose(8*b, (2, 2), strides=(2, 2))(drop2)
    merge1 = layers.concatenate([down4, up1], axis=3)
    x = conv_3x3_relu(merge1, 8*b)
    x = conv_3x3_relu(x, 8*b)
    x = conv_3x3_relu(x, 8*b)


    up2 = layers.Conv2DTranspose(4*b, (2, 2), strides=(2, 2))(x)
    merge2 = layers.concatenate([down3, up2], axis=3)
    x = conv_3x3_relu(merge2, 4*b)
    x = conv_3x3_relu(x, 4*b) 
    x = conv_3x3_relu(x, 4*b)


    up3 = layers.Conv2DTranspose(2*b, (2, 2), strides=(2, 2))(x)
    merge3 = layers.concatenate([down2, up3], axis=3)
    x = conv_3x3_relu(merge3, 2*b)
    x = conv_3x3_relu(x, 2*b) 
    x = conv_3x3_relu(x, 2*b)


    up4 = layers.Conv2DTranspose(b, (2, 2), strides=(2, 2))(x)
    merge4 = layers.concatenate([down1, up4], axis=3)
    x = conv_3x3_relu(merge4, b)
    x = conv_3x3_relu(x, b) 

    output = layers.Conv2D(c, (1, 1),name = 'result',activation = d)(x)

    Unet_model = models.Model(inputs=input, outputs=output)


    return Unet_model

# %% [markdown]
# ---
#
# ```# a = input_size
#     # b = 처음에 몇 채널로 시작할지
#     # c = output channel의 개수.
#     # d = activation function```

# %%
model = Unet((128, 128, 3), 32, 3, 'softmax')

# %% [markdown]
# # 2. Data load

# %%
import glob

data = glob.glob('.\\Data\\Chest CT Segmentation\\image\\image\\*.jpg')
label = glob.glob('.\\Data\\Chest CT Segmentation\\masks\\masks\\*.jpg')

# %%
print(len(data), len(label))
# Out:
# 16708 16708

# %%
def get_img(fstr):
    """
    jpg, png등의 영상을 읽어들임.
    numpy ndarray형으로 읽어들임.
    """
    img = cv2.imread(fstr)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (128, 128))
    #img = img/255.0
    #print(img.shape, img.dtype, np.max(img))
    return img

# %%
train_data = []
train_label = []

val_data = []
val_label = []

test_data = []
test_label = []


for i in range(8000):
    train_x = get_img(data[i])
    train_y = get_img(label[i])

    #train_y[train_y < 240] = 0  # remove artifacts
    #train_y[train_y >= 240] = 255
    
    #train_x = train_x/255.0
    #train_y = train_y/255.0
    
    train_data.append(train_x)
    train_label.append(train_y)
    
    
for i in range(2000):
    val_x = get_img(data[i+8000])
    val_y = get_img(label[i+8000])
    
    #val_y[val_y < 240] = 0
    #val_y[val_y >= 240] = 255
    
    #val_x = val_x/255.0
    #val_y = val_y/255.0
    
    val_data.append(val_x)
    val_label.append(val_y)
    

for i in range(1000):
    test_x = get_img(data[i+10000])
    test_y = get_img(label[i+10000])
    
    #test_y[test_y < 240] = 0
    #test_y[test_y >= 240] = 255
    
    #test_x = test_x/255.0
    #test_y = test_y/255.0
    
    test_data.append(test_x)
    test_label.append(test_y)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(221)
plt.imshow(train_data[15])

plt.subplot(222)
plt.imshow(train_label[15])

# %%
np.max(train_data[15])
# Out:
# 224

# %%
np.max(train_label[200])
# Out:
# 255

# %%
np.min(train_label[200])
# Out:
# 0

# %%
train_data = np.array(train_data)
train_label = np.array(train_label)

val_data = np.array(val_data)
val_label = np.array(val_label)

test_data = np.array(test_data)
test_label = np.array(test_label)


print(train_data.shape, train_label.shape, val_data.shape, val_label.shape, test_data.shape, test_label.shape, end='\n')
# Out:
# (8000, 128, 128, 3) (8000, 128, 128, 3) (2000, 128, 128, 3) (2000, 128, 128, 3) (1000, 128, 128, 3) (1000, 128, 128, 3)

# %%
train_data.shape
# Out:
# (8000, 128, 128, 3)

# %%
import datetime as dt

time_now = dt.datetime.now()
print(time_now.date())
# Out:
# 2022-05-26

# %%
np.save(f'./Data/Chest CT Segmentation/train_x_{time_now.date()}.npy', train_data)
np.save(f'./Data/Chest CT Segmentation/train_y_{time_now.date()}.npy', train_label)

np.save(f'./Data/Chest CT Segmentation/val_x_{time_now.date()}.npy', val_data)
np.save(f'./Data/Chest CT Segmentation/val_y_{time_now.date()}.npy', val_label)

np.save(f'./Data/Chest CT Segmentation/test_x_{time_now.date()}.npy', test_data)
np.save(f'./Data/Chest CT Segmentation/test_y_{time_now.date()}.npy', test_label)

# %%
#model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy, metrics='val_loss')
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-4), loss=tf.keras.losses.CategoricalCrossentropy(), metrics = ('accuracy', iou_gpu, dice_coef_gpu))

# %% [markdown]
# ### model checkpoint

# %%
from datetime import datetime

logdir="./log/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    f'./weight/{time_now.date()}_dice_model.h5',
    monitor='val_dice_coef_gpu',
    verbose=0,
    save_best_only=True,
    save_weights_only=False
)

#tensorboard_callback = TensorBoard(log_dir=logdir, histogram_freq=1)

# %%
history = model.fit(train_data, train_label, epochs = 100, batch_size = 100 ,
                    validation_data = (val_data, val_label), 
                    callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/100
#  2/80 [..............................] - ETA: 8s - loss: 18.5898 - accuracy: 0.1746 - iou_gpu: 1.1431 - dice_coef_gpu: 1.0666WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0147s vs `on_train_batch_end` time: 0.2152s). Check your callbacks.
# 80/80 [==============================] - ETA: 0s - loss: 7.5132 - accuracy: 0.3504 - iou_gpu: 4.7926 - dice_coef_gpu: 1.6044WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0156s vs `on_test_batch_end` time: 0.0468s). Check your callbacks.
# 80/80 [==============================] - 19s 242ms/step - loss: 7.5132 - accuracy: 0.3504 - iou_gpu: 4.7926 - dice_coef_gpu: 1.6044 - val_loss: 27.8307 - val_accuracy: 0.4443 - val_iou_gpu: 0.5480 - val_dice_coef_gpu: 0.7057
# Epoch 2/100
# 80/80 [==============================] - 19s 237ms/step - loss: 2.7752 - accuracy: 0.4490 - iou_gpu: 10.5352 - dice_coef_gpu: 1.8211 - val_loss: 19.3194 - val_accuracy: 0.4903 - val_iou_gpu: 1.0399 - val_dice_coef_gpu: 1.0009
# Epoch 3/100
# 80/80 [==============================] - 19s 239ms/step - loss: 1.7783 - accuracy: 0.5486 - iou_gpu: 14.3284 - dice_coef_gpu: 1.8687 - val_loss: 7.7687 - val_accuracy: 0.6735 - val_iou_gpu: 3.6257 - val_dice_coef_gpu: 1.5015
# Epoch 4/100
# 80/80 [==============================] - 19s 240ms/step - loss: 1.4974 - accuracy: 0.5681 - iou_gpu: 16.1232 - dice_coef_gpu: 1.8827 - val_loss: 3.9081 - val_accuracy: 0.6618 - val_iou_gpu: 8.1534 - val_dice_coef_gpu: 1.7180
# Epoch 5/100
# 80/80 [==============================] - 19s 241ms/step - loss: 1.4021 - accuracy: 0.5643 - iou_gpu: 16.6770 - dice_coef_gpu: 1.8865 - val_loss: 3.1443 - val_accuracy: 0.6351 - val_iou_gpu: 10.3597 - val_dice_coef_gpu: 1.7588
# Epoch 6/100
# 80/80 [==============================] - 19s 242ms/step - loss: 1.3546 - accuracy: 0.5616 - iou_gpu: 16.9574 - dice_coef_gpu: 1.8882 - val_loss: 2.9388 - val_accuracy: 0.6341 - val_iou_gpu: 11.0248 - val_dice_coef_gpu: 1.7713
# Epoch 7/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.3214 - accuracy: 0.5565 - iou_gpu: 17.1433 - dice_coef_gpu: 1.8893 - val_loss: 2.4551 - val_accuracy: 0.6116 - val_iou_gpu: 12.8410 - val_dice_coef_gpu: 1.7956
# Epoch 8/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.3051 - accuracy: 0.5542 - iou_gpu: 17.2241 - dice_coef_gpu: 1.8898 - val_loss: 2.4879 - val_accuracy: 0.6122 - val_iou_gpu: 12.8278 - val_dice_coef_gpu: 1.7977
# Epoch 9/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.2811 - accuracy: 0.5526 - iou_gpu: 17.3770 - dice_coef_gpu: 1.8906 - val_loss: 2.3506 - val_accuracy: 0.6125 - val_iou_gpu: 12.9029 - val_dice_coef_gpu: 1.8004
# Epoch 10/100
# 80/80 [==============================] - 19s 244ms/step - loss: 1.2664 - accuracy: 0.5457 - iou_gpu: 17.4012 - dice_coef_gpu: 1.8910 - val_loss: 2.4378 - val_accuracy: 0.6104 - val_iou_gpu: 13.0873 - val_dice_coef_gpu: 1.7994
# Epoch 11/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.2550 - accuracy: 0.5505 - iou_gpu: 17.4567 - dice_coef_gpu: 1.8912 - val_loss: 2.3494 - val_accuracy: 0.5935 - val_iou_gpu: 13.2520 - val_dice_coef_gpu: 1.8044
# Epoch 12/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.2449 - accuracy: 0.5494 - iou_gpu: 17.5136 - dice_coef_gpu: 1.8916 - val_loss: 2.1843 - val_accuracy: 0.5818 - val_iou_gpu: 13.8099 - val_dice_coef_gpu: 1.8112
# Epoch 13/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.2364 - accuracy: 0.5445 - iou_gpu: 17.5352 - dice_coef_gpu: 1.8917 - val_loss: 2.2510 - val_accuracy: 0.6031 - val_iou_gpu: 13.1952 - val_dice_coef_gpu: 1.8052
# Epoch 14/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.2231 - accuracy: 0.5448 - iou_gpu: 17.5954 - dice_coef_gpu: 1.8920 - val_loss: 2.7229 - val_accuracy: 0.6079 - val_iou_gpu: 12.9835 - val_dice_coef_gpu: 1.7987
# Epoch 15/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.2158 - accuracy: 0.5477 - iou_gpu: 17.6150 - dice_coef_gpu: 1.8921 - val_loss: 2.4048 - val_accuracy: 0.6031 - val_iou_gpu: 13.4954 - val_dice_coef_gpu: 1.8066
# Epoch 16/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.2125 - accuracy: 0.5486 - iou_gpu: 17.6650 - dice_coef_gpu: 1.8924 - val_loss: 2.3561 - val_accuracy: 0.6070 - val_iou_gpu: 13.2089 - val_dice_coef_gpu: 1.8034
# Epoch 17/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.2040 - accuracy: 0.5505 - iou_gpu: 17.6599 - dice_coef_gpu: 1.8923 - val_loss: 2.3928 - val_accuracy: 0.6257 - val_iou_gpu: 13.0937 - val_dice_coef_gpu: 1.8021
# Epoch 18/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.2005 - accuracy: 0.5478 - iou_gpu: 17.6877 - dice_coef_gpu: 1.8925 - val_loss: 2.4687 - val_accuracy: 0.6104 - val_iou_gpu: 13.1567 - val_dice_coef_gpu: 1.8011
# Epoch 19/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.2003 - accuracy: 0.5486 - iou_gpu: 17.6701 - dice_coef_gpu: 1.8924 - val_loss: 2.4647 - val_accuracy: 0.5835 - val_iou_gpu: 13.0814 - val_dice_coef_gpu: 1.8006
# Epoch 20/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1910 - accuracy: 0.5525 - iou_gpu: 17.7065 - dice_coef_gpu: 1.8927 - val_loss: 2.3444 - val_accuracy: 0.5867 - val_iou_gpu: 13.6098 - val_dice_coef_gpu: 1.8042
# Epoch 21/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1843 - accuracy: 0.5511 - iou_gpu: 17.7279 - dice_coef_gpu: 1.8927 - val_loss: 2.4069 - val_accuracy: 0.5890 - val_iou_gpu: 13.2506 - val_dice_coef_gpu: 1.8026
# Epoch 22/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1798 - accuracy: 0.5479 - iou_gpu: 17.7532 - dice_coef_gpu: 1.8930 - val_loss: 2.2123 - val_accuracy: 0.5712 - val_iou_gpu: 13.7202 - val_dice_coef_gpu: 1.8085
# Epoch 23/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1737 - accuracy: 0.5465 - iou_gpu: 17.7810 - dice_coef_gpu: 1.8932 - val_loss: 2.3478 - val_accuracy: 0.5949 - val_iou_gpu: 13.2358 - val_dice_coef_gpu: 1.8031
# Epoch 24/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1730 - accuracy: 0.5456 - iou_gpu: 17.7966 - dice_coef_gpu: 1.8932 - val_loss: 2.7151 - val_accuracy: 0.6103 - val_iou_gpu: 12.4675 - val_dice_coef_gpu: 1.7906
# Epoch 25/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1746 - accuracy: 0.5437 - iou_gpu: 17.7400 - dice_coef_gpu: 1.8927 - val_loss: 2.6085 - val_accuracy: 0.6135 - val_iou_gpu: 13.0781 - val_dice_coef_gpu: 1.7985
# Epoch 26/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1672 - accuracy: 0.5424 - iou_gpu: 17.8195 - dice_coef_gpu: 1.8934 - val_loss: 2.2165 - val_accuracy: 0.5647 - val_iou_gpu: 13.7304 - val_dice_coef_gpu: 1.8099
# Epoch 27/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1626 - accuracy: 0.5384 - iou_gpu: 17.8274 - dice_coef_gpu: 1.8932 - val_loss: 2.5668 - val_accuracy: 0.5588 - val_iou_gpu: 13.4805 - val_dice_coef_gpu: 1.8009
# Epoch 28/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1611 - accuracy: 0.5391 - iou_gpu: 17.8250 - dice_coef_gpu: 1.8933 - val_loss: 2.4477 - val_accuracy: 0.5620 - val_iou_gpu: 13.1782 - val_dice_coef_gpu: 1.8001
# Epoch 29/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1585 - accuracy: 0.5379 - iou_gpu: 17.8311 - dice_coef_gpu: 1.8933 - val_loss: 2.4639 - val_accuracy: 0.5882 - val_iou_gpu: 13.6311 - val_dice_coef_gpu: 1.8047
# Epoch 30/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1540 - accuracy: 0.5377 - iou_gpu: 17.8693 - dice_coef_gpu: 1.8936 - val_loss: 2.6086 - val_accuracy: 0.5820 - val_iou_gpu: 12.8073 - val_dice_coef_gpu: 1.7940
# Epoch 31/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1494 - accuracy: 0.5334 - iou_gpu: 17.8864 - dice_coef_gpu: 1.8937 - val_loss: 2.5873 - val_accuracy: 0.5864 - val_iou_gpu: 13.0169 - val_dice_coef_gpu: 1.7955
# Epoch 32/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1478 - accuracy: 0.5333 - iou_gpu: 17.8687 - dice_coef_gpu: 1.8936 - val_loss: 2.4716 - val_accuracy: 0.5815 - val_iou_gpu: 13.1022 - val_dice_coef_gpu: 1.7997
# Epoch 33/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1476 - accuracy: 0.5308 - iou_gpu: 17.8932 - dice_coef_gpu: 1.8937 - val_loss: 2.7915 - val_accuracy: 0.6133 - val_iou_gpu: 12.5407 - val_dice_coef_gpu: 1.7916
# Epoch 34/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1476 - accuracy: 0.5309 - iou_gpu: 17.8903 - dice_coef_gpu: 1.8937 - val_loss: 3.0290 - val_accuracy: 0.5803 - val_iou_gpu: 12.7858 - val_dice_coef_gpu: 1.7876
# Epoch 35/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1426 - accuracy: 0.5252 - iou_gpu: 17.9161 - dice_coef_gpu: 1.8939 - val_loss: 2.5225 - val_accuracy: 0.5503 - val_iou_gpu: 12.9736 - val_dice_coef_gpu: 1.7988
# Epoch 36/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1402 - accuracy: 0.5250 - iou_gpu: 17.8910 - dice_coef_gpu: 1.8936 - val_loss: 2.6193 - val_accuracy: 0.5526 - val_iou_gpu: 13.2810 - val_dice_coef_gpu: 1.7989
# Epoch 37/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1399 - accuracy: 0.5222 - iou_gpu: 17.9265 - dice_coef_gpu: 1.8939 - val_loss: 2.8661 - val_accuracy: 0.5553 - val_iou_gpu: 13.0899 - val_dice_coef_gpu: 1.7930
# Epoch 38/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1361 - accuracy: 0.5195 - iou_gpu: 17.9228 - dice_coef_gpu: 1.8938 - val_loss: 2.9104 - val_accuracy: 0.5664 - val_iou_gpu: 13.0808 - val_dice_coef_gpu: 1.7940
# Epoch 39/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1378 - accuracy: 0.5157 - iou_gpu: 17.9336 - dice_coef_gpu: 1.8940 - val_loss: 2.7678 - val_accuracy: 0.5517 - val_iou_gpu: 12.9972 - val_dice_coef_gpu: 1.7939
# Epoch 40/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1365 - accuracy: 0.5111 - iou_gpu: 17.8943 - dice_coef_gpu: 1.8936 - val_loss: 2.8006 - val_accuracy: 0.5557 - val_iou_gpu: 12.7609 - val_dice_coef_gpu: 1.7918
# Epoch 41/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1339 - accuracy: 0.5091 - iou_gpu: 17.9247 - dice_coef_gpu: 1.8938 - val_loss: 2.7085 - val_accuracy: 0.5549 - val_iou_gpu: 13.0912 - val_dice_coef_gpu: 1.7970
# Epoch 42/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1302 - accuracy: 0.5056 - iou_gpu: 17.9615 - dice_coef_gpu: 1.8941 - val_loss: 2.4924 - val_accuracy: 0.5269 - val_iou_gpu: 13.0499 - val_dice_coef_gpu: 1.7989
# Epoch 43/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.3887 - accuracy: 0.5065 - iou_gpu: 16.6618 - dice_coef_gpu: 1.8858 - val_loss: 6.0675 - val_accuracy: 0.3853 - val_iou_gpu: 7.4961 - val_dice_coef_gpu: 1.7070
# Epoch 44/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.3755 - accuracy: 0.5030 - iou_gpu: 16.7692 - dice_coef_gpu: 1.8870 - val_loss: 2.9546 - val_accuracy: 0.5597 - val_iou_gpu: 11.1828 - val_dice_coef_gpu: 1.7785
# Epoch 45/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1975 - accuracy: 0.4896 - iou_gpu: 17.6799 - dice_coef_gpu: 1.8925 - val_loss: 2.1511 - val_accuracy: 0.5558 - val_iou_gpu: 13.1919 - val_dice_coef_gpu: 1.8061
# Epoch 46/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1655 - accuracy: 0.4849 - iou_gpu: 17.8235 - dice_coef_gpu: 1.8933 - val_loss: 2.1203 - val_accuracy: 0.5550 - val_iou_gpu: 13.6783 - val_dice_coef_gpu: 1.8110
# Epoch 47/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1516 - accuracy: 0.4839 - iou_gpu: 17.8714 - dice_coef_gpu: 1.8937 - val_loss: 2.1572 - val_accuracy: 0.5474 - val_iou_gpu: 13.6453 - val_dice_coef_gpu: 1.8100
# Epoch 48/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1445 - accuracy: 0.4802 - iou_gpu: 17.8962 - dice_coef_gpu: 1.8937 - val_loss: 2.1910 - val_accuracy: 0.5330 - val_iou_gpu: 13.8323 - val_dice_coef_gpu: 1.8114
# Epoch 49/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1377 - accuracy: 0.4789 - iou_gpu: 17.9379 - dice_coef_gpu: 1.8939 - val_loss: 2.0779 - val_accuracy: 0.5244 - val_iou_gpu: 13.8950 - val_dice_coef_gpu: 1.8133
# Epoch 50/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1338 - accuracy: 0.4770 - iou_gpu: 17.9316 - dice_coef_gpu: 1.8938 - val_loss: 2.3010 - val_accuracy: 0.5311 - val_iou_gpu: 14.1147 - val_dice_coef_gpu: 1.8126
# Epoch 51/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1302 - accuracy: 0.4756 - iou_gpu: 17.9529 - dice_coef_gpu: 1.8940 - val_loss: 2.1694 - val_accuracy: 0.5171 - val_iou_gpu: 13.8239 - val_dice_coef_gpu: 1.8120
# Epoch 52/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1270 - accuracy: 0.4740 - iou_gpu: 17.9761 - dice_coef_gpu: 1.8942 - val_loss: 2.2337 - val_accuracy: 0.5198 - val_iou_gpu: 13.9934 - val_dice_coef_gpu: 1.8122
# Epoch 53/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1256 - accuracy: 0.4702 - iou_gpu: 17.9609 - dice_coef_gpu: 1.8939 - val_loss: 2.2511 - val_accuracy: 0.5241 - val_iou_gpu: 13.6546 - val_dice_coef_gpu: 1.8092
# Epoch 54/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1235 - accuracy: 0.4684 - iou_gpu: 17.9659 - dice_coef_gpu: 1.8941 - val_loss: 2.2400 - val_accuracy: 0.5083 - val_iou_gpu: 13.8474 - val_dice_coef_gpu: 1.8104
# Epoch 55/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1210 - accuracy: 0.4678 - iou_gpu: 17.9801 - dice_coef_gpu: 1.8941 - val_loss: 2.2101 - val_accuracy: 0.5118 - val_iou_gpu: 13.9867 - val_dice_coef_gpu: 1.8126
# Epoch 56/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1198 - accuracy: 0.4660 - iou_gpu: 17.9836 - dice_coef_gpu: 1.8942 - val_loss: 2.3334 - val_accuracy: 0.5056 - val_iou_gpu: 13.7218 - val_dice_coef_gpu: 1.8077
# Epoch 57/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1178 - accuracy: 0.4624 - iou_gpu: 18.0010 - dice_coef_gpu: 1.8942 - val_loss: 2.3811 - val_accuracy: 0.5138 - val_iou_gpu: 13.8865 - val_dice_coef_gpu: 1.8091
# Epoch 58/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1152 - accuracy: 0.4608 - iou_gpu: 18.0120 - dice_coef_gpu: 1.8944 - val_loss: 2.3151 - val_accuracy: 0.5298 - val_iou_gpu: 13.7671 - val_dice_coef_gpu: 1.8096
# Epoch 59/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1154 - accuracy: 0.4561 - iou_gpu: 18.0085 - dice_coef_gpu: 1.8943 - val_loss: 2.3370 - val_accuracy: 0.5060 - val_iou_gpu: 13.7663 - val_dice_coef_gpu: 1.8083
# Epoch 60/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1137 - accuracy: 0.4540 - iou_gpu: 18.0175 - dice_coef_gpu: 1.8944 - val_loss: 2.5440 - val_accuracy: 0.5277 - val_iou_gpu: 13.1951 - val_dice_coef_gpu: 1.7997
# Epoch 61/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1121 - accuracy: 0.4533 - iou_gpu: 18.0256 - dice_coef_gpu: 1.8945 - val_loss: 2.4061 - val_accuracy: 0.5074 - val_iou_gpu: 13.4058 - val_dice_coef_gpu: 1.8042
# Epoch 62/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1106 - accuracy: 0.4507 - iou_gpu: 18.0137 - dice_coef_gpu: 1.8942 - val_loss: 2.5183 - val_accuracy: 0.5096 - val_iou_gpu: 13.3413 - val_dice_coef_gpu: 1.8015
# Epoch 63/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1089 - accuracy: 0.4508 - iou_gpu: 18.0369 - dice_coef_gpu: 1.8945 - val_loss: 2.4227 - val_accuracy: 0.5143 - val_iou_gpu: 13.5379 - val_dice_coef_gpu: 1.8053
# Epoch 64/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1089 - accuracy: 0.4473 - iou_gpu: 18.0307 - dice_coef_gpu: 1.8945 - val_loss: 2.3428 - val_accuracy: 0.5012 - val_iou_gpu: 13.6092 - val_dice_coef_gpu: 1.8076
# Epoch 65/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1098 - accuracy: 0.4468 - iou_gpu: 18.0259 - dice_coef_gpu: 1.8946 - val_loss: 2.3537 - val_accuracy: 0.5061 - val_iou_gpu: 13.6095 - val_dice_coef_gpu: 1.8074
# Epoch 66/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1091 - accuracy: 0.4464 - iou_gpu: 18.0318 - dice_coef_gpu: 1.8945 - val_loss: 2.5445 - val_accuracy: 0.5189 - val_iou_gpu: 13.5504 - val_dice_coef_gpu: 1.8037
# Epoch 67/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1061 - accuracy: 0.4446 - iou_gpu: 18.0513 - dice_coef_gpu: 1.8945 - val_loss: 2.5251 - val_accuracy: 0.5026 - val_iou_gpu: 13.6320 - val_dice_coef_gpu: 1.8048
# Epoch 68/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1052 - accuracy: 0.4419 - iou_gpu: 18.0387 - dice_coef_gpu: 1.8944 - val_loss: 2.4120 - val_accuracy: 0.5014 - val_iou_gpu: 13.5957 - val_dice_coef_gpu: 1.8060
# Epoch 69/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.1043 - accuracy: 0.4412 - iou_gpu: 18.0590 - dice_coef_gpu: 1.8945 - val_loss: 2.6971 - val_accuracy: 0.5092 - val_iou_gpu: 13.7166 - val_dice_coef_gpu: 1.8036
# Epoch 70/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1061 - accuracy: 0.4403 - iou_gpu: 18.0252 - dice_coef_gpu: 1.8944 - val_loss: 2.4820 - val_accuracy: 0.5049 - val_iou_gpu: 13.0489 - val_dice_coef_gpu: 1.7999
# Epoch 71/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1036 - accuracy: 0.4377 - iou_gpu: 18.0307 - dice_coef_gpu: 1.8943 - val_loss: 2.6626 - val_accuracy: 0.5193 - val_iou_gpu: 13.1331 - val_dice_coef_gpu: 1.7986
# Epoch 72/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.1011 - accuracy: 0.4356 - iou_gpu: 18.0624 - dice_coef_gpu: 1.8944 - val_loss: 2.6185 - val_accuracy: 0.5071 - val_iou_gpu: 13.2210 - val_dice_coef_gpu: 1.7996
# Epoch 73/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1003 - accuracy: 0.4345 - iou_gpu: 18.0712 - dice_coef_gpu: 1.8948 - val_loss: 2.6451 - val_accuracy: 0.4985 - val_iou_gpu: 13.2030 - val_dice_coef_gpu: 1.7996
# Epoch 74/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.1003 - accuracy: 0.4342 - iou_gpu: 18.0614 - dice_coef_gpu: 1.8947 - val_loss: 2.5295 - val_accuracy: 0.4997 - val_iou_gpu: 13.2989 - val_dice_coef_gpu: 1.8019
# Epoch 75/100
# 80/80 [==============================] - 20s 246ms/step - loss: 1.0997 - accuracy: 0.4331 - iou_gpu: 18.0570 - dice_coef_gpu: 1.8946 - val_loss: 2.5892 - val_accuracy: 0.4910 - val_iou_gpu: 13.2895 - val_dice_coef_gpu: 1.8006
# Epoch 76/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0983 - accuracy: 0.4310 - iou_gpu: 18.0655 - dice_coef_gpu: 1.8947 - val_loss: 2.6672 - val_accuracy: 0.4970 - val_iou_gpu: 13.4130 - val_dice_coef_gpu: 1.8014
# Epoch 77/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0973 - accuracy: 0.4310 - iou_gpu: 18.0671 - dice_coef_gpu: 1.8946 - val_loss: 2.4616 - val_accuracy: 0.4743 - val_iou_gpu: 13.4010 - val_dice_coef_gpu: 1.8033
# Epoch 78/100
# 80/80 [==============================] - 19s 244ms/step - loss: 1.0977 - accuracy: 0.4284 - iou_gpu: 18.0563 - dice_coef_gpu: 1.8945 - val_loss: 2.6916 - val_accuracy: 0.4937 - val_iou_gpu: 13.1181 - val_dice_coef_gpu: 1.7979
# Epoch 79/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.0952 - accuracy: 0.4256 - iou_gpu: 18.0903 - dice_coef_gpu: 1.8947 - val_loss: 2.5835 - val_accuracy: 0.5026 - val_iou_gpu: 13.3415 - val_dice_coef_gpu: 1.8024
# Epoch 80/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.0937 - accuracy: 0.4267 - iou_gpu: 18.0955 - dice_coef_gpu: 1.8948 - val_loss: 2.8073 - val_accuracy: 0.4981 - val_iou_gpu: 13.1009 - val_dice_coef_gpu: 1.7955
# Epoch 81/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.0933 - accuracy: 0.4249 - iou_gpu: 18.0890 - dice_coef_gpu: 1.8947 - val_loss: 2.7182 - val_accuracy: 0.4971 - val_iou_gpu: 12.8194 - val_dice_coef_gpu: 1.7950
# Epoch 82/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.0929 - accuracy: 0.4254 - iou_gpu: 18.0962 - dice_coef_gpu: 1.8949 - val_loss: 2.6607 - val_accuracy: 0.4958 - val_iou_gpu: 13.3538 - val_dice_coef_gpu: 1.8012
# Epoch 83/100
# 80/80 [==============================] - 19s 244ms/step - loss: 1.0928 - accuracy: 0.4248 - iou_gpu: 18.1107 - dice_coef_gpu: 1.8950 - val_loss: 2.8366 - val_accuracy: 0.4981 - val_iou_gpu: 13.1131 - val_dice_coef_gpu: 1.7951
# Epoch 84/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.0933 - accuracy: 0.4252 - iou_gpu: 18.1068 - dice_coef_gpu: 1.8948 - val_loss: 2.6642 - val_accuracy: 0.4937 - val_iou_gpu: 13.2016 - val_dice_coef_gpu: 1.7985
# Epoch 85/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.0930 - accuracy: 0.4216 - iou_gpu: 18.0698 - dice_coef_gpu: 1.8946 - val_loss: 2.8210 - val_accuracy: 0.4828 - val_iou_gpu: 13.0137 - val_dice_coef_gpu: 1.7950
# Epoch 86/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.0910 - accuracy: 0.4190 - iou_gpu: 18.1204 - dice_coef_gpu: 1.8948 - val_loss: 2.7730 - val_accuracy: 0.4852 - val_iou_gpu: 13.2722 - val_dice_coef_gpu: 1.7990
# Epoch 87/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.0892 - accuracy: 0.4201 - iou_gpu: 18.0931 - dice_coef_gpu: 1.8946 - val_loss: 2.6233 - val_accuracy: 0.4898 - val_iou_gpu: 13.1001 - val_dice_coef_gpu: 1.7992
# Epoch 88/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.0893 - accuracy: 0.4178 - iou_gpu: 18.1060 - dice_coef_gpu: 1.8949 - val_loss: 2.6042 - val_accuracy: 0.5001 - val_iou_gpu: 13.5260 - val_dice_coef_gpu: 1.8039
# Epoch 89/100
# 80/80 [==============================] - 19s 244ms/step - loss: 1.0902 - accuracy: 0.4181 - iou_gpu: 18.1128 - dice_coef_gpu: 1.8948 - val_loss: 2.7631 - val_accuracy: 0.5045 - val_iou_gpu: 13.3047 - val_dice_coef_gpu: 1.7998
# Epoch 90/100
# 80/80 [==============================] - 19s 243ms/step - loss: 1.0890 - accuracy: 0.4189 - iou_gpu: 18.1037 - dice_coef_gpu: 1.8948 - val_loss: 2.5639 - val_accuracy: 0.4725 - val_iou_gpu: 13.6747 - val_dice_coef_gpu: 1.8040
# Epoch 91/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.0892 - accuracy: 0.4166 - iou_gpu: 18.0983 - dice_coef_gpu: 1.8946 - val_loss: 2.4588 - val_accuracy: 0.4748 - val_iou_gpu: 13.2914 - val_dice_coef_gpu: 1.8023
# Epoch 92/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.0859 - accuracy: 0.4171 - iou_gpu: 18.1213 - dice_coef_gpu: 1.8949 - val_loss: 2.7195 - val_accuracy: 0.4911 - val_iou_gpu: 13.0898 - val_dice_coef_gpu: 1.7975
# Epoch 93/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.0850 - accuracy: 0.4156 - iou_gpu: 18.1221 - dice_coef_gpu: 1.8949 - val_loss: 2.6764 - val_accuracy: 0.4847 - val_iou_gpu: 13.1700 - val_dice_coef_gpu: 1.7987
# Epoch 94/100
# 80/80 [==============================] - 20s 244ms/step - loss: 1.0853 - accuracy: 0.4151 - iou_gpu: 18.1191 - dice_coef_gpu: 1.8947 - val_loss: 2.9021 - val_accuracy: 0.4912 - val_iou_gpu: 12.8243 - val_dice_coef_gpu: 1.7919
# Epoch 95/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0855 - accuracy: 0.4154 - iou_gpu: 18.1128 - dice_coef_gpu: 1.8949 - val_loss: 2.9085 - val_accuracy: 0.4927 - val_iou_gpu: 13.0508 - val_dice_coef_gpu: 1.7944
# Epoch 96/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0849 - accuracy: 0.4133 - iou_gpu: 18.1215 - dice_coef_gpu: 1.8948 - val_loss: 2.9165 - val_accuracy: 0.4964 - val_iou_gpu: 12.7646 - val_dice_coef_gpu: 1.7919
# Epoch 97/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0844 - accuracy: 0.4130 - iou_gpu: 18.1343 - dice_coef_gpu: 1.8951 - val_loss: 2.9072 - val_accuracy: 0.4902 - val_iou_gpu: 12.8124 - val_dice_coef_gpu: 1.7921
# Epoch 98/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0830 - accuracy: 0.4107 - iou_gpu: 18.1285 - dice_coef_gpu: 1.8949 - val_loss: 2.7395 - val_accuracy: 0.4775 - val_iou_gpu: 13.1276 - val_dice_coef_gpu: 1.7972
# Epoch 99/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0824 - accuracy: 0.4113 - iou_gpu: 18.1287 - dice_coef_gpu: 1.8948 - val_loss: 2.5853 - val_accuracy: 0.4836 - val_iou_gpu: 13.0557 - val_dice_coef_gpu: 1.7988
# Epoch 100/100
# 80/80 [==============================] - 20s 245ms/step - loss: 1.0817 - accuracy: 0.4107 - iou_gpu: 18.1285 - dice_coef_gpu: 1.8948 - val_loss: 2.7189 - val_accuracy: 0.4896 - val_iou_gpu: 12.9660 - val_dice_coef_gpu: 1.7956

# %% [markdown]
# ## Plot

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

val_dice = history.history['val_dice_coef_gpu']

# %%
plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.1))

plt.plot(train_loss, 'r', label='Train loss')
plt.plot(val_loss, 'b', label='Validation loss')

plt.legend()

# %%
train_dice = history.history['dice_coef_gpu']
val_dice = history.history['val_dice_coef_gpu']

plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.3))

plt.plot(train_dice, 'r', label='Train Dice coefficient')
plt.plot(val_dice, 'b', label='Validation Dice coefficient')

plt.legend()

# %%
train_iou = history.history['iou_gpu']
val_iou = history.history['val_iou_gpu']

plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.3))

plt.plot(train_iou, 'r', label='Train IOU')
plt.plot(val_iou, 'b', label='Validation IOU')

plt.legend()

# %% [markdown]
# ---
# # Test

# %%
test_data.shape
# Out:
# (1000, 128, 128, 3)

# %%
# test_data, test_label

predict_result = model.predict(test_data)

# %%
q = 300

plt.figure(figsize = (15, 15))

plt.subplot(231)
plt.imshow(test_data[q])

plt.subplot(232)
plt.imshow(test_label[q])

plt.subplot(233)
plt.imshow(predict_result[q])


#print(iou_gpu(test_label[q], predict_result[q]))
