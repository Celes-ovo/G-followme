# %% [markdown]
# # 1. Model 구현

# %%
import cv2, numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
tf.version
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\GC\\anaconda3\\envs\\sangmin_env\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Dice coefficient, IoU Metric

from tensorflow.keras import backend as K

def iou_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + K.epsilon())
	
def dice_coef_gpu(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %%
def BCEDiceloss(y_true, y_pred):
    # BCE loss + Dice coefficient
    bce = tf.keras.losses.BinaryCrossentropy()
    
    bce_loss = bce(y_true, y_pred)
    dice_loss = dice_coef_gpu(y_true, y_pred)
    
    return bce_loss + dice_loss

# %%
import keras
from keras import models, layers


def conv_3x3_relu(x, n):
    x = layers.Conv2D(n, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(max_value=None, negative_slope=0, threshold=0)(x)

    return x



def Unet(a, b, c, d):
    # a = input_size
    # b = 처음에 몇 채널로 시작할지
    # c = output channel의 개수.
    # d = activation function

    input = layers.Input(a)


    #Encoder

    x = conv_3x3_relu(input, b)
    down1 = conv_3x3_relu(x, b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down1)


    x = conv_3x3_relu(x, 2*b)
    down2 = conv_3x3_relu(x, 2*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down2)


    x = conv_3x3_relu(x, 4*b)
    down3 = conv_3x3_relu(x, 4*b)
    x = layers.MaxPool2D(pool_size=(2, 2))(down3)


    x = conv_3x3_relu(x, 8*b)
    down4 = conv_3x3_relu(x, 8*b)
    drop1 = layers.Dropout(0.3)(down4)
    x = layers.MaxPool2D(pool_size=(2, 2))(drop1)




    # Bottleneck

    x = conv_3x3_relu(x, 16*b)
    x = conv_3x3_relu(x, 16*b)
    drop2 = layers.Dropout(0.3)(x)




    # Decoder

    up1 = layers.Conv2DTranspose(8*b, (2, 2), strides=(2, 2))(drop2)
    merge1 = layers.concatenate([down4, up1], axis=3)
    x = conv_3x3_relu(merge1, 8*b)
    x = conv_3x3_relu(x, 8*b)
    x = conv_3x3_relu(x, 8*b)


    up2 = layers.Conv2DTranspose(4*b, (2, 2), strides=(2, 2))(x)
    merge2 = layers.concatenate([down3, up2], axis=3)
    x = conv_3x3_relu(merge2, 4*b)
    x = conv_3x3_relu(x, 4*b) 
    x = conv_3x3_relu(x, 4*b)


    up3 = layers.Conv2DTranspose(2*b, (2, 2), strides=(2, 2))(x)
    merge3 = layers.concatenate([down2, up3], axis=3)
    x = conv_3x3_relu(merge3, 2*b)
    x = conv_3x3_relu(x, 2*b) 
    x = conv_3x3_relu(x, 2*b)


    up4 = layers.Conv2DTranspose(b, (2, 2), strides=(2, 2))(x)
    merge4 = layers.concatenate([down1, up4], axis=3)
    x = conv_3x3_relu(merge4, b)
    x = conv_3x3_relu(x, b) 

    output = layers.Conv2D(c, (1, 1),name = 'result',activation = d)(x)

    Unet_model = models.Model(inputs=input, outputs=output)


    return Unet_model

# %% [markdown]
# ---
#
# ```# a = input_size
#     # b = 처음에 몇 채널로 시작할지
#     # c = output channel의 개수.
#     # d = activation function```

# %%
model = Unet((128, 128, 3), 32, 4, 'softmax')

# %% [markdown]
# # 2. Data load

# %%
import glob

data = glob.glob('.\\Data\\Chest CT Segmentation\\image\\image\\*.jpg')
label = glob.glob('.\\Data\\Chest CT Segmentation\\masks\\masks\\*.jpg')

# %%
print(len(data), len(label))
# Out:
# 16708 16708

# %%
def get_img(fstr):
    """
    jpg, png등의 영상을 읽어들임.
    numpy ndarray형으로 읽어들임.
    """
    img = cv2.imread(fstr)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (128, 128))
    #img = img/255.0
    #print(img.shape, img.dtype, np.max(img))
    return img

# %%
train_y = get_img(label[0])

print(train_y.shape)

c1, c2, c3 = cv2.split(train_y)

c4 = np.sum(train_y, axis=2)
plt.imshow(c4)

print(c1.shape)
print(c4.shape)
# Out:
# (128, 128, 3)
# (128, 128)
# (128, 128)

# %%
train_y_2 = np.stack((c1, c2, c3, c4), axis=2)

plt.imshow(train_y_2)
print(train_y_2.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (128, 128, 4)

# %%
train_data = []
train_label = []

test_data = []
test_label = []


for i in range(10000):
    train_x = get_img(data[i])
    train_y = get_img(label[i])
    
    c1, c2, c3 = cv2.split(train_y)
    
    c4 = np.sum(train_y, axis=2)
    
    train_y_2 = np.stack((c1, c2, c3, c4), axis=2)
    train_y_2 = np.clip(train_y_2, 0, 255)

    #train_y[train_y < 240] = 0  # remove artifacts
    #train_y[train_y >= 240] = 255
    
    #train_x = train_x/255.0
    #train_y = train_y/255.0
    
    train_data.append(train_x)
    train_label.append(train_y_2)
    

for i in range(6708):
    test_x = get_img(data[i+10000])
    test_y = get_img(label[i+10000])
    
    c1, c2, c3 = cv2.split(test_y)
    
    c4 = np.sum(test_y, axis=2)
    
    test_y_2 = np.stack((c1, c2, c3, c4), axis=2)
    test_y_2 = np.clip(test_y_2, 0, 255)
    
    #test_y[test_y < 240] = 0
    #test_y[test_y >= 240] = 255
    
    #test_x = test_x/255.0
    #test_y = test_y/255.0
    
    test_data.append(test_x)
    test_label.append(test_y_2)

# %%
train_label[15].shape
# Out:
# (128, 128, 4)

# %%
plt.figure(figsize=(15, 15))

plt.subplot(221)
plt.imshow(train_data[15])

plt.subplot(222)
plt.imshow(train_label[15])

# %%
plt.figure(figsize=(7, 7))

plt.imshow(train_label[15][..., 3])

# %%
np.max(train_data[15])
# Out:
# 224

# %%
np.max(train_label[200])
# Out:
# 255

# %%
np.min(train_label[200])
# Out:
# 0

# %%
train_data = np.array(train_data)
train_label = np.array(train_label)

test_data = np.array(test_data)
test_label = np.array(test_label)


print(train_data.shape, train_label.shape, test_data.shape, test_label.shape, end='\n')
# Out:
# (10000, 128, 128, 3) (10000, 128, 128, 4) (6708, 128, 128, 3) (6708, 128, 128, 4)

# %%
from sklearn.model_selection import train_test_split

train_x, val_x, train_y, val_y = train_test_split(train_data, train_label, test_size=0.2, random_state=77)

# %%
train_x = np.array(train_x)
train_y = np.array(train_y)

val_x = np.array(val_x)
val_y = np.array(val_y)


print(train_x.shape)
print(train_y.shape)
print(val_x.shape)
print(val_y.shape)
# Out:
# (8000, 128, 128, 3)
# (8000, 128, 128, 4)
# (2000, 128, 128, 3)
# (2000, 128, 128, 4)

# %%
import datetime as dt

time_now = dt.datetime.now()
print(time_now.date())
# Out:
# 2022-06-07

# %%
#model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy, metrics='val_loss')
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-4), loss=tf.keras.losses.CategoricalCrossentropy(), metrics = ('accuracy', iou_gpu, dice_coef_gpu, BCEDiceloss))

# %% [markdown]
# ### model checkpoint

# %%
from datetime import datetime

logdir="./log/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    f'./weight/{time_now.date()}_loss_model.h5',
    monitor='val_loss',
    #monitor='val_BCEDiceloss',
    verbose=0,
    save_best_only=True,
    save_weights_only=False
)

tensorboard_callback = TensorBoard(log_dir=logdir, histogram_freq=1)

# %%
history = model.fit(train_x, train_y, epochs = 200, batch_size = 100 ,
                    validation_data = (val_x, val_y), 
                    callbacks=[model_checkpoint_callback, tensorboard_callback])
# Out:
# Epoch 1/200
#  1/80 [..............................] - ETA: 0s - loss: 91.5691 - accuracy: 0.2430 - iou_gpu: 0.3830 - dice_coef_gpu: 0.5538 - BCEDiceloss: 18.1313WARNING:tensorflow:From C:\Users\GC\anaconda3\envs\sangmin_env\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/80 [..............................] - ETA: 12s - loss: 87.7588 - accuracy: 0.2432 - iou_gpu: 0.3959 - dice_coef_gpu: 0.5671 - BCEDiceloss: 17.1609WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0197s vs `on_train_batch_end` time: 0.2802s). Check your callbacks.
# 80/80 [==============================] - ETA: 0s - loss: 52.4690 - accuracy: 0.3720 - iou_gpu: 0.7205 - dice_coef_gpu: 0.8287 - BCEDiceloss: 6.2632WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0080s vs `on_test_batch_end` time: 0.0640s). Check your callbacks.
# 80/80 [==============================] - 21s 261ms/step - loss: 52.4690 - accuracy: 0.3720 - iou_gpu: 0.7205 - dice_coef_gpu: 0.8287 - BCEDiceloss: 6.2632 - val_loss: 62.3194 - val_accuracy: 0.3449 - val_iou_gpu: 0.5057 - val_dice_coef_gpu: 0.6715 - val_BCEDiceloss: 10.6251
# Epoch 2/200
# 80/80 [==============================] - 21s 258ms/step - loss: 41.8574 - accuracy: 0.4620 - iou_gpu: 0.8870 - dice_coef_gpu: 0.9400 - BCEDiceloss: 2.6871 - val_loss: 62.0093 - val_accuracy: 0.4139 - val_iou_gpu: 0.5168 - val_dice_coef_gpu: 0.6811 - val_BCEDiceloss: 10.4586
# Epoch 3/200
# 80/80 [==============================] - 21s 259ms/step - loss: 40.2308 - accuracy: 0.5110 - iou_gpu: 0.9226 - dice_coef_gpu: 0.9597 - BCEDiceloss: 2.1026 - val_loss: 43.7290 - val_accuracy: 0.4888 - val_iou_gpu: 0.8031 - val_dice_coef_gpu: 0.8907 - val_BCEDiceloss: 3.9608
# Epoch 4/200
# 80/80 [==============================] - 21s 261ms/step - loss: 39.7957 - accuracy: 0.5603 - iou_gpu: 0.9311 - dice_coef_gpu: 0.9643 - BCEDiceloss: 1.9618 - val_loss: 39.8828 - val_accuracy: 0.4940 - val_iou_gpu: 0.8927 - val_dice_coef_gpu: 0.9433 - val_BCEDiceloss: 2.4764
# Epoch 5/200
# 80/80 [==============================] - 21s 261ms/step - loss: 39.5153 - accuracy: 0.6011 - iou_gpu: 0.9372 - dice_coef_gpu: 0.9676 - BCEDiceloss: 1.8633 - val_loss: 38.7206 - val_accuracy: 0.5971 - val_iou_gpu: 0.9229 - val_dice_coef_gpu: 0.9599 - val_BCEDiceloss: 2.0242
# Epoch 6/200
# 80/80 [==============================] - 21s 262ms/step - loss: 39.3455 - accuracy: 0.6111 - iou_gpu: 0.9413 - dice_coef_gpu: 0.9698 - BCEDiceloss: 1.8025 - val_loss: 38.2660 - val_accuracy: 0.5938 - val_iou_gpu: 0.9362 - val_dice_coef_gpu: 0.9671 - val_BCEDiceloss: 1.8428
# Epoch 7/200
# 80/80 [==============================] - 21s 264ms/step - loss: 39.2645 - accuracy: 0.6151 - iou_gpu: 0.9428 - dice_coef_gpu: 0.9706 - BCEDiceloss: 1.7779 - val_loss: 38.1783 - val_accuracy: 0.6164 - val_iou_gpu: 0.9375 - val_dice_coef_gpu: 0.9677 - val_BCEDiceloss: 1.8202
# Epoch 8/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.2040 - accuracy: 0.6159 - iou_gpu: 0.9441 - dice_coef_gpu: 0.9712 - BCEDiceloss: 1.7584 - val_loss: 38.0652 - val_accuracy: 0.6577 - val_iou_gpu: 0.9412 - val_dice_coef_gpu: 0.9697 - val_BCEDiceloss: 1.7743
# Epoch 9/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.1764 - accuracy: 0.6209 - iou_gpu: 0.9445 - dice_coef_gpu: 0.9714 - BCEDiceloss: 1.7508 - val_loss: 37.9900 - val_accuracy: 0.6186 - val_iou_gpu: 0.9415 - val_dice_coef_gpu: 0.9698 - val_BCEDiceloss: 1.7581
# Epoch 10/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.1466 - accuracy: 0.6222 - iou_gpu: 0.9449 - dice_coef_gpu: 0.9717 - BCEDiceloss: 1.7426 - val_loss: 37.9785 - val_accuracy: 0.6476 - val_iou_gpu: 0.9420 - val_dice_coef_gpu: 0.9701 - val_BCEDiceloss: 1.7526
# Epoch 11/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.1140 - accuracy: 0.6267 - iou_gpu: 0.9453 - dice_coef_gpu: 0.9719 - BCEDiceloss: 1.7331 - val_loss: 37.9708 - val_accuracy: 0.6370 - val_iou_gpu: 0.9425 - val_dice_coef_gpu: 0.9704 - val_BCEDiceloss: 1.7489
# Epoch 12/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.1026 - accuracy: 0.6274 - iou_gpu: 0.9456 - dice_coef_gpu: 0.9720 - BCEDiceloss: 1.7298 - val_loss: 37.9390 - val_accuracy: 0.6529 - val_iou_gpu: 0.9415 - val_dice_coef_gpu: 0.9699 - val_BCEDiceloss: 1.7484
# Epoch 13/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.0904 - accuracy: 0.6269 - iou_gpu: 0.9457 - dice_coef_gpu: 0.9721 - BCEDiceloss: 1.7267 - val_loss: 37.9141 - val_accuracy: 0.6411 - val_iou_gpu: 0.9439 - val_dice_coef_gpu: 0.9711 - val_BCEDiceloss: 1.7284
# Epoch 14/200
# 80/80 [==============================] - 21s 267ms/step - loss: 39.0785 - accuracy: 0.6322 - iou_gpu: 0.9459 - dice_coef_gpu: 0.9722 - BCEDiceloss: 1.7234 - val_loss: 37.9019 - val_accuracy: 0.6394 - val_iou_gpu: 0.9439 - val_dice_coef_gpu: 0.9711 - val_BCEDiceloss: 1.7263
# Epoch 15/200
# 80/80 [==============================] - 21s 263ms/step - loss: 39.0627 - accuracy: 0.6294 - iou_gpu: 0.9461 - dice_coef_gpu: 0.9723 - BCEDiceloss: 1.7184 - val_loss: 37.9167 - val_accuracy: 0.6361 - val_iou_gpu: 0.9426 - val_dice_coef_gpu: 0.9704 - val_BCEDiceloss: 1.7384
# Epoch 16/200
# 80/80 [==============================] - 21s 266ms/step - loss: 39.0499 - accuracy: 0.6284 - iou_gpu: 0.9463 - dice_coef_gpu: 0.9724 - BCEDiceloss: 1.7150 - val_loss: 37.8731 - val_accuracy: 0.6270 - val_iou_gpu: 0.9445 - val_dice_coef_gpu: 0.9715 - val_BCEDiceloss: 1.7159
# Epoch 17/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.0415 - accuracy: 0.6280 - iou_gpu: 0.9463 - dice_coef_gpu: 0.9724 - BCEDiceloss: 1.7128 - val_loss: 37.8652 - val_accuracy: 0.6422 - val_iou_gpu: 0.9451 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.7107
# Epoch 18/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.0378 - accuracy: 0.6293 - iou_gpu: 0.9464 - dice_coef_gpu: 0.9724 - BCEDiceloss: 1.7124 - val_loss: 37.8463 - val_accuracy: 0.6632 - val_iou_gpu: 0.9441 - val_dice_coef_gpu: 0.9712 - val_BCEDiceloss: 1.7130
# Epoch 19/200
# 80/80 [==============================] - 21s 267ms/step - loss: 39.0280 - accuracy: 0.6319 - iou_gpu: 0.9465 - dice_coef_gpu: 0.9725 - BCEDiceloss: 1.7089 - val_loss: 37.8422 - val_accuracy: 0.6452 - val_iou_gpu: 0.9451 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.7059
# Epoch 20/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.0231 - accuracy: 0.6310 - iou_gpu: 0.9466 - dice_coef_gpu: 0.9726 - BCEDiceloss: 1.7075 - val_loss: 37.8660 - val_accuracy: 0.6071 - val_iou_gpu: 0.9457 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.7077
# Epoch 21/200
# 80/80 [==============================] - 21s 266ms/step - loss: 39.0136 - accuracy: 0.6271 - iou_gpu: 0.9467 - dice_coef_gpu: 0.9726 - BCEDiceloss: 1.7051 - val_loss: 37.8316 - val_accuracy: 0.6423 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.7032
# Epoch 22/200
# 80/80 [==============================] - 21s 265ms/step - loss: 39.0105 - accuracy: 0.6239 - iou_gpu: 0.9465 - dice_coef_gpu: 0.9725 - BCEDiceloss: 1.7046 - val_loss: 37.8265 - val_accuracy: 0.6473 - val_iou_gpu: 0.9451 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.7033
# Epoch 23/200
# 80/80 [==============================] - 21s 260ms/step - loss: 39.0024 - accuracy: 0.6260 - iou_gpu: 0.9468 - dice_coef_gpu: 0.9727 - BCEDiceloss: 1.7018 - val_loss: 37.8383 - val_accuracy: 0.6369 - val_iou_gpu: 0.9439 - val_dice_coef_gpu: 0.9712 - val_BCEDiceloss: 1.7136
# Epoch 24/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.9966 - accuracy: 0.6252 - iou_gpu: 0.9468 - dice_coef_gpu: 0.9727 - BCEDiceloss: 1.7004 - val_loss: 37.8215 - val_accuracy: 0.6546 - val_iou_gpu: 0.9451 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.7027
# Epoch 25/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9950 - accuracy: 0.6259 - iou_gpu: 0.9468 - dice_coef_gpu: 0.9726 - BCEDiceloss: 1.7003 - val_loss: 37.8205 - val_accuracy: 0.6398 - val_iou_gpu: 0.9439 - val_dice_coef_gpu: 0.9711 - val_BCEDiceloss: 1.7096
# Epoch 26/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9866 - accuracy: 0.6224 - iou_gpu: 0.9470 - dice_coef_gpu: 0.9728 - BCEDiceloss: 1.6976 - val_loss: 37.8220 - val_accuracy: 0.6446 - val_iou_gpu: 0.9448 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.7052
# Epoch 27/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9841 - accuracy: 0.6235 - iou_gpu: 0.9470 - dice_coef_gpu: 0.9728 - BCEDiceloss: 1.6965 - val_loss: 37.8045 - val_accuracy: 0.6287 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6973
# Epoch 28/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.9792 - accuracy: 0.6179 - iou_gpu: 0.9470 - dice_coef_gpu: 0.9728 - BCEDiceloss: 1.6956 - val_loss: 37.8031 - val_accuracy: 0.6273 - val_iou_gpu: 0.9451 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6991
# Epoch 29/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9822 - accuracy: 0.6159 - iou_gpu: 0.9471 - dice_coef_gpu: 0.9728 - BCEDiceloss: 1.6963 - val_loss: 37.8323 - val_accuracy: 0.6354 - val_iou_gpu: 0.9449 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.7068
# Epoch 30/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9725 - accuracy: 0.6161 - iou_gpu: 0.9471 - dice_coef_gpu: 0.9728 - BCEDiceloss: 1.6936 - val_loss: 37.8186 - val_accuracy: 0.6316 - val_iou_gpu: 0.9439 - val_dice_coef_gpu: 0.9712 - val_BCEDiceloss: 1.7097
# Epoch 31/200
# 80/80 [==============================] - 21s 257ms/step - loss: 39.0056 - accuracy: 0.6072 - iou_gpu: 0.9466 - dice_coef_gpu: 0.9726 - BCEDiceloss: 1.7049 - val_loss: 37.8377 - val_accuracy: 0.6234 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.7099
# Epoch 32/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9762 - accuracy: 0.6076 - iou_gpu: 0.9470 - dice_coef_gpu: 0.9728 - BCEDiceloss: 1.6957 - val_loss: 37.8010 - val_accuracy: 0.6116 - val_iou_gpu: 0.9445 - val_dice_coef_gpu: 0.9714 - val_BCEDiceloss: 1.7026
# Epoch 33/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9637 - accuracy: 0.6085 - iou_gpu: 0.9473 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6907 - val_loss: 37.7843 - val_accuracy: 0.6384 - val_iou_gpu: 0.9439 - val_dice_coef_gpu: 0.9711 - val_BCEDiceloss: 1.7021
# Epoch 34/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.9605 - accuracy: 0.6083 - iou_gpu: 0.9471 - dice_coef_gpu: 0.9729 - BCEDiceloss: 1.6906 - val_loss: 37.7850 - val_accuracy: 0.6074 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.6972
# Epoch 35/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9567 - accuracy: 0.6068 - iou_gpu: 0.9473 - dice_coef_gpu: 0.9729 - BCEDiceloss: 1.6892 - val_loss: 37.7915 - val_accuracy: 0.6061 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6955
# Epoch 36/200
# 80/80 [==============================] - 21s 261ms/step - loss: 38.9493 - accuracy: 0.6077 - iou_gpu: 0.9474 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6869 - val_loss: 37.7755 - val_accuracy: 0.6287 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6916
# Epoch 37/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.9489 - accuracy: 0.6063 - iou_gpu: 0.9474 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6867 - val_loss: 37.7775 - val_accuracy: 0.6098 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6930
# Epoch 38/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.9462 - accuracy: 0.6029 - iou_gpu: 0.9474 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6862 - val_loss: 37.7732 - val_accuracy: 0.6204 - val_iou_gpu: 0.9455 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6894
# Epoch 39/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.9419 - accuracy: 0.6022 - iou_gpu: 0.9475 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6846 - val_loss: 37.7731 - val_accuracy: 0.6210 - val_iou_gpu: 0.9444 - val_dice_coef_gpu: 0.9714 - val_BCEDiceloss: 1.6968
# Epoch 40/200
# 80/80 [==============================] - 21s 261ms/step - loss: 38.9399 - accuracy: 0.6042 - iou_gpu: 0.9474 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6843 - val_loss: 37.7715 - val_accuracy: 0.6176 - val_iou_gpu: 0.9458 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6880
# Epoch 41/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9412 - accuracy: 0.5955 - iou_gpu: 0.9473 - dice_coef_gpu: 0.9729 - BCEDiceloss: 1.6854 - val_loss: 37.7747 - val_accuracy: 0.6169 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.6956
# Epoch 42/200
# 80/80 [==============================] - 20s 255ms/step - loss: 38.9369 - accuracy: 0.5955 - iou_gpu: 0.9474 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6840 - val_loss: 37.7744 - val_accuracy: 0.6000 - val_iou_gpu: 0.9454 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6917
# Epoch 43/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9338 - accuracy: 0.5945 - iou_gpu: 0.9475 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6829 - val_loss: 37.7733 - val_accuracy: 0.6132 - val_iou_gpu: 0.9444 - val_dice_coef_gpu: 0.9714 - val_BCEDiceloss: 1.6980
# Epoch 44/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9454 - accuracy: 0.5952 - iou_gpu: 0.9473 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6877 - val_loss: 37.7873 - val_accuracy: 0.6014 - val_iou_gpu: 0.9458 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6934
# Epoch 45/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9398 - accuracy: 0.5922 - iou_gpu: 0.9475 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6855 - val_loss: 37.7910 - val_accuracy: 0.6033 - val_iou_gpu: 0.9449 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6997
# Epoch 46/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9341 - accuracy: 0.5893 - iou_gpu: 0.9475 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6842 - val_loss: 37.7628 - val_accuracy: 0.5991 - val_iou_gpu: 0.9449 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6927
# Epoch 47/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.9362 - accuracy: 0.5883 - iou_gpu: 0.9474 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6853 - val_loss: 37.7614 - val_accuracy: 0.6103 - val_iou_gpu: 0.9460 - val_dice_coef_gpu: 0.9723 - val_BCEDiceloss: 1.6863
# Epoch 48/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9294 - accuracy: 0.5891 - iou_gpu: 0.9476 - dice_coef_gpu: 0.9731 - BCEDiceloss: 1.6829 - val_loss: 37.7704 - val_accuracy: 0.5975 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6943
# Epoch 49/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9264 - accuracy: 0.5826 - iou_gpu: 0.9476 - dice_coef_gpu: 0.9731 - BCEDiceloss: 1.6824 - val_loss: 37.7592 - val_accuracy: 0.6030 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6913
# Epoch 50/200
# 80/80 [==============================] - 21s 257ms/step - loss: 39.1812 - accuracy: 0.5774 - iou_gpu: 0.9434 - dice_coef_gpu: 0.9708 - BCEDiceloss: 1.7725 - val_loss: 41.1044 - val_accuracy: 0.2486 - val_iou_gpu: 0.9327 - val_dice_coef_gpu: 0.9651 - val_BCEDiceloss: 2.5462
# Epoch 51/200
# 80/80 [==============================] - 20s 256ms/step - loss: 39.2236 - accuracy: 0.5409 - iou_gpu: 0.9430 - dice_coef_gpu: 0.9707 - BCEDiceloss: 1.7949 - val_loss: 38.3023 - val_accuracy: 0.4040 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.8378
# Epoch 52/200
# 80/80 [==============================] - 21s 257ms/step - loss: 39.0212 - accuracy: 0.5414 - iou_gpu: 0.9464 - dice_coef_gpu: 0.9725 - BCEDiceloss: 1.7227 - val_loss: 37.8194 - val_accuracy: 0.5791 - val_iou_gpu: 0.9417 - val_dice_coef_gpu: 0.9699 - val_BCEDiceloss: 1.7356
# Epoch 53/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.9646 - accuracy: 0.5418 - iou_gpu: 0.9472 - dice_coef_gpu: 0.9729 - BCEDiceloss: 1.7017 - val_loss: 37.7916 - val_accuracy: 0.5750 - val_iou_gpu: 0.9432 - val_dice_coef_gpu: 0.9707 - val_BCEDiceloss: 1.7177
# Epoch 54/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.9497 - accuracy: 0.5409 - iou_gpu: 0.9474 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6958 - val_loss: 37.7838 - val_accuracy: 0.5801 - val_iou_gpu: 0.9419 - val_dice_coef_gpu: 0.9701 - val_BCEDiceloss: 1.7230
# Epoch 55/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9401 - accuracy: 0.5404 - iou_gpu: 0.9475 - dice_coef_gpu: 0.9730 - BCEDiceloss: 1.6924 - val_loss: 37.7594 - val_accuracy: 0.5411 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9715 - val_BCEDiceloss: 1.6993
# Epoch 56/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9316 - accuracy: 0.5415 - iou_gpu: 0.9475 - dice_coef_gpu: 0.9731 - BCEDiceloss: 1.6896 - val_loss: 37.7555 - val_accuracy: 0.5585 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9715 - val_BCEDiceloss: 1.6989
# Epoch 57/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.9273 - accuracy: 0.5444 - iou_gpu: 0.9476 - dice_coef_gpu: 0.9731 - BCEDiceloss: 1.6878 - val_loss: 37.7491 - val_accuracy: 0.5582 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6953
# Epoch 58/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9228 - accuracy: 0.5437 - iou_gpu: 0.9477 - dice_coef_gpu: 0.9731 - BCEDiceloss: 1.6865 - val_loss: 37.7488 - val_accuracy: 0.5369 - val_iou_gpu: 0.9454 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6933
# Epoch 59/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9197 - accuracy: 0.5428 - iou_gpu: 0.9478 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6852 - val_loss: 37.7477 - val_accuracy: 0.5425 - val_iou_gpu: 0.9448 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.6973
# Epoch 60/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.9162 - accuracy: 0.5415 - iou_gpu: 0.9477 - dice_coef_gpu: 0.9731 - BCEDiceloss: 1.6852 - val_loss: 37.7445 - val_accuracy: 0.5324 - val_iou_gpu: 0.9461 - val_dice_coef_gpu: 0.9723 - val_BCEDiceloss: 1.6884
# Epoch 61/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9141 - accuracy: 0.5384 - iou_gpu: 0.9477 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6845 - val_loss: 37.7386 - val_accuracy: 0.5170 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6921
# Epoch 62/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9125 - accuracy: 0.5363 - iou_gpu: 0.9478 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6840 - val_loss: 37.7437 - val_accuracy: 0.5441 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.6975
# Epoch 63/200
# 80/80 [==============================] - 21s 256ms/step - loss: 38.9094 - accuracy: 0.5403 - iou_gpu: 0.9479 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6831 - val_loss: 37.7404 - val_accuracy: 0.5455 - val_iou_gpu: 0.9445 - val_dice_coef_gpu: 0.9715 - val_BCEDiceloss: 1.6984
# Epoch 64/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9071 - accuracy: 0.5373 - iou_gpu: 0.9478 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6830 - val_loss: 37.7457 - val_accuracy: 0.5460 - val_iou_gpu: 0.9464 - val_dice_coef_gpu: 0.9724 - val_BCEDiceloss: 1.6877
# Epoch 65/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.9059 - accuracy: 0.5400 - iou_gpu: 0.9479 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6825 - val_loss: 37.7392 - val_accuracy: 0.5279 - val_iou_gpu: 0.9448 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.6965
# Epoch 66/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.9028 - accuracy: 0.5386 - iou_gpu: 0.9479 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6819 - val_loss: 37.7429 - val_accuracy: 0.5598 - val_iou_gpu: 0.9456 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6931
# Epoch 67/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.9032 - accuracy: 0.5390 - iou_gpu: 0.9477 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6821 - val_loss: 37.7381 - val_accuracy: 0.5222 - val_iou_gpu: 0.9458 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6901
# Epoch 68/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.9013 - accuracy: 0.5369 - iou_gpu: 0.9479 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6815 - val_loss: 37.7378 - val_accuracy: 0.5346 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6937
# Epoch 69/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8994 - accuracy: 0.5354 - iou_gpu: 0.9479 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6812 - val_loss: 37.7399 - val_accuracy: 0.5288 - val_iou_gpu: 0.9449 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6975
# Epoch 70/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.8986 - accuracy: 0.5353 - iou_gpu: 0.9479 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6813 - val_loss: 37.7360 - val_accuracy: 0.5190 - val_iou_gpu: 0.9449 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6959
# Epoch 71/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8980 - accuracy: 0.5336 - iou_gpu: 0.9479 - dice_coef_gpu: 0.9732 - BCEDiceloss: 1.6815 - val_loss: 37.7354 - val_accuracy: 0.5275 - val_iou_gpu: 0.9455 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6923
# Epoch 72/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.8979 - accuracy: 0.5333 - iou_gpu: 0.9480 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6814 - val_loss: 37.7382 - val_accuracy: 0.5384 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6956
# Epoch 73/200
# 80/80 [==============================] - 21s 256ms/step - loss: 38.8952 - accuracy: 0.5350 - iou_gpu: 0.9480 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6807 - val_loss: 37.7355 - val_accuracy: 0.5499 - val_iou_gpu: 0.9454 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6932
# Epoch 74/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8931 - accuracy: 0.5340 - iou_gpu: 0.9480 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6803 - val_loss: 37.7310 - val_accuracy: 0.5251 - val_iou_gpu: 0.9459 - val_dice_coef_gpu: 0.9722 - val_BCEDiceloss: 1.6894
# Epoch 75/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8904 - accuracy: 0.5349 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6794 - val_loss: 37.7385 - val_accuracy: 0.5461 - val_iou_gpu: 0.9446 - val_dice_coef_gpu: 0.9715 - val_BCEDiceloss: 1.6998
# Epoch 76/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8900 - accuracy: 0.5332 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6794 - val_loss: 37.7356 - val_accuracy: 0.5280 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9715 - val_BCEDiceloss: 1.6980
# Epoch 77/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8899 - accuracy: 0.5328 - iou_gpu: 0.9480 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6798 - val_loss: 37.7339 - val_accuracy: 0.5197 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6959
# Epoch 78/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8882 - accuracy: 0.5338 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6794 - val_loss: 37.7379 - val_accuracy: 0.5263 - val_iou_gpu: 0.9454 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6937
# Epoch 79/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8866 - accuracy: 0.5352 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6785 - val_loss: 37.7356 - val_accuracy: 0.5442 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6970
# Epoch 80/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8854 - accuracy: 0.5329 - iou_gpu: 0.9480 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6786 - val_loss: 37.7350 - val_accuracy: 0.5419 - val_iou_gpu: 0.9458 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6917
# Epoch 81/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8848 - accuracy: 0.5323 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6784 - val_loss: 37.7294 - val_accuracy: 0.5422 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6954
# Epoch 82/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8847 - accuracy: 0.5296 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6789 - val_loss: 37.7322 - val_accuracy: 0.5157 - val_iou_gpu: 0.9462 - val_dice_coef_gpu: 0.9723 - val_BCEDiceloss: 1.6889
# Epoch 83/200
# 80/80 [==============================] - 21s 261ms/step - loss: 38.8857 - accuracy: 0.5293 - iou_gpu: 0.9480 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6795 - val_loss: 37.7282 - val_accuracy: 0.5579 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6947
# Epoch 84/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8834 - accuracy: 0.5300 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6787 - val_loss: 37.7355 - val_accuracy: 0.5289 - val_iou_gpu: 0.9443 - val_dice_coef_gpu: 0.9713 - val_BCEDiceloss: 1.7011
# Epoch 85/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8804 - accuracy: 0.5291 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6779 - val_loss: 37.7339 - val_accuracy: 0.5247 - val_iou_gpu: 0.9456 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6932
# Epoch 86/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8802 - accuracy: 0.5311 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6778 - val_loss: 37.7329 - val_accuracy: 0.5384 - val_iou_gpu: 0.9454 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6946
# Epoch 87/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8800 - accuracy: 0.5299 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6778 - val_loss: 37.7406 - val_accuracy: 0.4922 - val_iou_gpu: 0.9445 - val_dice_coef_gpu: 0.9714 - val_BCEDiceloss: 1.7012
# Epoch 88/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.8780 - accuracy: 0.5280 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6773 - val_loss: 37.7327 - val_accuracy: 0.5466 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6960
# Epoch 89/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8782 - accuracy: 0.5255 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9733 - BCEDiceloss: 1.6777 - val_loss: 37.7404 - val_accuracy: 0.5359 - val_iou_gpu: 0.9441 - val_dice_coef_gpu: 0.9712 - val_BCEDiceloss: 1.7047
# Epoch 90/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8767 - accuracy: 0.5268 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6775 - val_loss: 37.7364 - val_accuracy: 0.5522 - val_iou_gpu: 0.9444 - val_dice_coef_gpu: 0.9714 - val_BCEDiceloss: 1.7012
# Epoch 91/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8771 - accuracy: 0.5264 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6776 - val_loss: 37.7280 - val_accuracy: 0.5163 - val_iou_gpu: 0.9457 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6914
# Epoch 92/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8749 - accuracy: 0.5267 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6768 - val_loss: 37.7341 - val_accuracy: 0.5121 - val_iou_gpu: 0.9458 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6921
# Epoch 93/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8745 - accuracy: 0.5240 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6768 - val_loss: 37.7286 - val_accuracy: 0.5298 - val_iou_gpu: 0.9447 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.6999
# Epoch 94/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8733 - accuracy: 0.5239 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6770 - val_loss: 37.7337 - val_accuracy: 0.5131 - val_iou_gpu: 0.9457 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6934
# Epoch 95/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8743 - accuracy: 0.5237 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6770 - val_loss: 37.7255 - val_accuracy: 0.5535 - val_iou_gpu: 0.9455 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6932
# Epoch 96/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8732 - accuracy: 0.5214 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6769 - val_loss: 37.7273 - val_accuracy: 0.5167 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6937
# Epoch 97/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8733 - accuracy: 0.5228 - iou_gpu: 0.9481 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6772 - val_loss: 37.7373 - val_accuracy: 0.5116 - val_iou_gpu: 0.9451 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6983
# Epoch 98/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8708 - accuracy: 0.5232 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6765 - val_loss: 37.7286 - val_accuracy: 0.5393 - val_iou_gpu: 0.9443 - val_dice_coef_gpu: 0.9713 - val_BCEDiceloss: 1.7014
# Epoch 99/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.8677 - accuracy: 0.5217 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6755 - val_loss: 37.7242 - val_accuracy: 0.5408 - val_iou_gpu: 0.9460 - val_dice_coef_gpu: 0.9722 - val_BCEDiceloss: 1.6894
# Epoch 100/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8691 - accuracy: 0.5186 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6760 - val_loss: 37.7201 - val_accuracy: 0.5359 - val_iou_gpu: 0.9458 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6905
# Epoch 101/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8672 - accuracy: 0.5189 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6752 - val_loss: 37.7288 - val_accuracy: 0.5362 - val_iou_gpu: 0.9457 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6933
# Epoch 102/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8665 - accuracy: 0.5172 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6754 - val_loss: 37.7387 - val_accuracy: 0.5526 - val_iou_gpu: 0.9444 - val_dice_coef_gpu: 0.9714 - val_BCEDiceloss: 1.7035
# Epoch 103/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.8659 - accuracy: 0.5191 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6751 - val_loss: 37.7264 - val_accuracy: 0.5522 - val_iou_gpu: 0.9451 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6970
# Epoch 104/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8673 - accuracy: 0.5168 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6759 - val_loss: 37.7320 - val_accuracy: 0.5447 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6975
# Epoch 105/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8661 - accuracy: 0.5155 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6756 - val_loss: 37.7192 - val_accuracy: 0.5335 - val_iou_gpu: 0.9461 - val_dice_coef_gpu: 0.9723 - val_BCEDiceloss: 1.6899
# Epoch 106/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8641 - accuracy: 0.5156 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6748 - val_loss: 37.7287 - val_accuracy: 0.5352 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6958
# Epoch 107/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.8629 - accuracy: 0.5143 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6749 - val_loss: 37.7311 - val_accuracy: 0.5087 - val_iou_gpu: 0.9457 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6931
# Epoch 108/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8619 - accuracy: 0.5128 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6744 - val_loss: 37.7200 - val_accuracy: 0.4860 - val_iou_gpu: 0.9455 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6927
# Epoch 109/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8622 - accuracy: 0.5115 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6748 - val_loss: 37.7207 - val_accuracy: 0.5028 - val_iou_gpu: 0.9463 - val_dice_coef_gpu: 0.9724 - val_BCEDiceloss: 1.6881
# Epoch 110/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.8635 - accuracy: 0.5144 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6751 - val_loss: 37.7238 - val_accuracy: 0.5033 - val_iou_gpu: 0.9449 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.6975
# Epoch 111/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8620 - accuracy: 0.5126 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6748 - val_loss: 37.7261 - val_accuracy: 0.5281 - val_iou_gpu: 0.9455 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6939
# Epoch 112/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8623 - accuracy: 0.5126 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6748 - val_loss: 37.7231 - val_accuracy: 0.5028 - val_iou_gpu: 0.9449 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6970
# Epoch 113/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8616 - accuracy: 0.5085 - iou_gpu: 0.9482 - dice_coef_gpu: 0.9734 - BCEDiceloss: 1.6748 - val_loss: 37.7293 - val_accuracy: 0.5155 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6980
# Epoch 114/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8606 - accuracy: 0.5104 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6746 - val_loss: 37.7190 - val_accuracy: 0.5217 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6951
# Epoch 115/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8573 - accuracy: 0.5115 - iou_gpu: 0.9484 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6735 - val_loss: 37.7242 - val_accuracy: 0.4824 - val_iou_gpu: 0.9460 - val_dice_coef_gpu: 0.9722 - val_BCEDiceloss: 1.6906
# Epoch 116/200
# 80/80 [==============================] - 21s 256ms/step - loss: 38.8575 - accuracy: 0.5090 - iou_gpu: 0.9483 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6734 - val_loss: 37.7213 - val_accuracy: 0.4777 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6938
# Epoch 117/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8577 - accuracy: 0.5094 - iou_gpu: 0.9484 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6736 - val_loss: 37.7190 - val_accuracy: 0.5103 - val_iou_gpu: 0.9454 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6930
# Epoch 118/200
# 80/80 [==============================] - 20s 256ms/step - loss: 38.8558 - accuracy: 0.5090 - iou_gpu: 0.9484 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.6730 - val_loss: 37.7216 - val_accuracy: 0.5376 - val_iou_gpu: 0.9456 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6930
# Epoch 119/200
# 80/80 [==============================] - 21s 260ms/step - loss: 38.8555 - accuracy: 0.5068 - iou_gpu: 0.9484 - dice_coef_gpu: 0.9735 - BCEDiceloss: 1.
- val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6986
# Epoch 192/200
# 80/80 [==============================] - 21s 256ms/step - loss: 38.8244 - accuracy: 0.4965 - iou_gpu: 0.9488 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6669 - val_loss: 37.7226 - val_accuracy: 0.5263 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.7009
# Epoch 193/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8248 - accuracy: 0.4974 - iou_gpu: 0.9488 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6672 - val_loss: 37.7205 - val_accuracy: 0.5134 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6986
# Epoch 194/200
# 80/80 [==============================] - 21s 259ms/step - loss: 38.8241 - accuracy: 0.5008 - iou_gpu: 0.9488 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6669 - val_loss: 37.7279 - val_accuracy: 0.4818 - val_iou_gpu: 0.9452 - val_dice_coef_gpu: 0.9718 - val_BCEDiceloss: 1.6982
# Epoch 195/200
# 80/80 [==============================] - 21s 257ms/step - loss: 38.8232 - accuracy: 0.4950 - iou_gpu: 0.9489 - dice_coef_gpu: 0.9738 - BCEDiceloss: 1.6669 - val_loss: 37.7300 - val_accuracy: 0.5465 - val_iou_gpu: 0.9455 - val_dice_coef_gpu: 0.9720 - val_BCEDiceloss: 1.6997
# Epoch 196/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.8260 - accuracy: 0.4968 - iou_gpu: 0.9487 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6678 - val_loss: 37.7242 - val_accuracy: 0.4791 - val_iou_gpu: 0.9457 - val_dice_coef_gpu: 0.9721 - val_BCEDiceloss: 1.6951
# Epoch 197/200
# 80/80 [==============================] - 21s 256ms/step - loss: 38.8237 - accuracy: 0.4960 - iou_gpu: 0.9487 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6673 - val_loss: 37.7195 - val_accuracy: 0.5233 - val_iou_gpu: 0.9450 - val_dice_coef_gpu: 0.9717 - val_BCEDiceloss: 1.6991
# Epoch 198/200
# 80/80 [==============================] - 21s 258ms/step - loss: 38.8234 - accuracy: 0.4952 - iou_gpu: 0.9487 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6672 - val_loss: 37.7207 - val_accuracy: 0.5135 - val_iou_gpu: 0.9460 - val_dice_coef_gpu: 0.9722 - val_BCEDiceloss: 1.6946
# Epoch 199/200
# 80/80 [==============================] - 21s 256ms/step - loss: 38.8223 - accuracy: 0.4945 - iou_gpu: 0.9488 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6669 - val_loss: 37.7263 - val_accuracy: 0.5443 - val_iou_gpu: 0.9448 - val_dice_coef_gpu: 0.9716 - val_BCEDiceloss: 1.7034
# Epoch 200/200
# 80/80 [==============================] - 21s 256ms/step - loss: 38.8216 - accuracy: 0.4958 - iou_gpu: 0.9488 - dice_coef_gpu: 0.9737 - BCEDiceloss: 1.6669 - val_loss: 37.7170 - val_accuracy: 0.4799 - val_iou_gpu: 0.9453 - val_dice_coef_gpu: 0.9719 - val_BCEDiceloss: 1.6993

# %% [markdown]
# ## Plot

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

val_dice = history.history['val_dice_coef_gpu']

# %%
plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.1))

plt.plot(train_loss, 'r', label='Train loss')
plt.plot(val_loss, 'b', label='Validation loss')

plt.legend()

# %%
train_dice = history.history['dice_coef_gpu']
val_dice = history.history['val_dice_coef_gpu']

plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.3))

plt.plot(train_dice, 'r', label='Train Dice coefficient')
plt.plot(val_dice, 'b', label='Validation Dice coefficient')

plt.legend()

# %%
train_iou = history.history['iou_gpu']
val_iou = history.history['val_iou_gpu']

plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.3))

plt.plot(train_iou, 'r', label='Train IOU')
plt.plot(val_iou, 'b', label='Validation IOU')

plt.legend()

# %%
# BCEDiceloss

train_BCEDiceloss = history.history['BCEDiceloss']
val_BCEDiceloss = history.history['val_BCEDiceloss']

plt.figure(figsize = (10, 10))
#plt.ylim((0, 0.3))

plt.plot(train_BCEDiceloss, 'r', label='Train BCEDiceloss')
plt.plot(val_BCEDiceloss, 'b', label='Validation BCEDiceloss')

plt.legend()

# %%
bce_2 = np.array(history.history['val_BCEDiceloss'])
dice_2 = np.array(history.history['val_dice_coef_gpu'])

loss_sub = (bce_2 - dice_2)
loss_sub.shape
# Out:
# (200,)

# %%
plt.figure(figsize = (10, 10))

plt.plot(loss_sub)

# %% [markdown]
# ---
# # Test

# %%
test_data.shape
# Out:
# (6708, 128, 128, 3)

# %%
model_2 = Unet((128, 128, 3), 32, 4, 'softmax')
model_2.load_weights('./weight/2022-06-07_loss_model.h5')

# %%
# test_data, test_label

predict_result = model_2.predict(test_data)

# %%
q = 300

plt.figure(figsize = (15, 15))

plt.subplot(231)
plt.imshow(test_data[q])

plt.subplot(232)
plt.imshow(test_label[q][..., :3])
#plt.imshow(test_label[q])

plt.subplot(233)

predict_result_2 = predict_result[q].copy()
predict_result_2[predict_result_2 < 0.45] = 0
predict_result_2[predict_result_2 >= 0.45] = 1

#plt.imshow(predict_result[q][..., :3])
plt.imshow(predict_result_2[..., :3])


#print(iou_gpu(test_label[q], predict_result[q]))

# %%
for i in range(4):
    plt.subplots()
    plt.imshow(predict_result[20][..., i])

# %%
for q in range(10, 850, 50):
    plt.figure(figsize = (15, 15))

    plt.subplot(231)
    plt.imshow(test_data[q])

    plt.subplot(232)
    plt.imshow(test_label[q][..., :3])
    #plt.imshow(test_label[q])

    plt.subplot(233)

    predict_result_2 = predict_result[q].copy()
    predict_result_2[predict_result_2 < 0.45] = 0
    predict_result_2[predict_result_2 >= 0.45] = 1

    #plt.imshow(predict_result[q][..., :3])
    #print(q)
    plt.imshow(predict_result_2[..., :3])


    #print(iou_gpu(test_label[q], predict_result[q]))

# %% [markdown]
# ---

# %%
# test_data, test_label

predict_train = model_2.predict(train_x)

# %%
q = 300

plt.figure(figsize = (15, 15))

plt.subplot(231)
plt.imshow(train_x[q])

plt.subplot(232)
plt.imshow(train_y[q][..., :3])

plt.subplot(233)
plt.imshow(predict_train[q][..., :3])


#print(iou_gpu(test_label[q], predict_result[q]))

# %%
for i in range(4):
    plt.subplots()
    plt.imshow(predict_train[300][..., i])

# %% [markdown]
# ---
# ## Tensorboard

# %%
# %tensorboard !kill 5972
# Out:
# ERROR: Failed to launch TensorBoard (exited with 2).
# Contents of stderr:
# 2022-06-07 16:36:14.715130: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cudart64_101.dll
# usage: tensorboard [-h] [--helpfull] {serve,dev} ...
# tensorboard: error: invalid choice: '!kill' (choose from 'serve', 'dev')

# %%
# %tensorboard --logdir=logdir
# Out:
# Reusing TensorBoard on port 6006 (pid 5972), started 5 days, 2:26:34 ago. (Use '!kill 5972' to kill it.)
#       <iframe id="tensorboard-frame-5b755acf0634776a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5b755acf0634776a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
